# %%
# !pip install supabase

# %%
import os
from dotenv import load_dotenv
from supabase import create_client, Client

load_dotenv()

url = os.environ.get("SUPABASE_URL")
key = os.environ.get("SUPABASE_KEY")
supabase = create_client(url, key)

# %%
response = supabase.table(table_name='employees').select('*').execute()
if response.data is not None:
    print(response.data)
else:
    print("Error:", response.error)
# Out:
# [{'EmployeeID': 'af2af254-7906-4bcc-9f48-017d0272565e', 'EmployeeName': 'Richard Davis', 'Department': 'Accounts', 'JobTitle': 'Programmer, systems', 'AccessLevel': 'None', 'SalesAccess': True, 'PlanningAccess': True, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': True, 'AccountsAccess': True, 'SettingsAccess': True}, {'EmployeeID': '1902f73b-5030-4843-b2c2-7222e6937975', 'EmployeeName': 'Bianca Garrett', 'Department': 'Settings', 'JobTitle': 'Physiological scientist', 'AccessLevel': 'Full', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': True, 'MaintenanceAccess': False, 'QualityAccess': True, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': True}, {'EmployeeID': 'e6215472-f44d-408f-843f-cecc24286407', 'EmployeeName': 'Melinda Thomas', 'Department': 'Dispatch', 'JobTitle': 'Librarian, academic', 'AccessLevel': 'None', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': True, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': False}, {'EmployeeID': 'd629dacb-dccc-4b4a-b310-b2ce96ae03cc', 'EmployeeName': 'Kenneth Lowe V', 'Department': 'Planning', 'JobTitle': 'Doctor, general practice', 'AccessLevel': 'Full', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': True, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': True, 'SettingsAccess': True}, {'EmployeeID': 'a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04', 'EmployeeName': 'Jessica Johnson', 'Department': 'Sales', 'JobTitle': 'Personal assistant', 'AccessLevel': 'Limited', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': True, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': False}, {'EmployeeID': '82f213a8-780b-402b-9962-8eaf63ef56d1', 'EmployeeName': 'William Oconnell', 'Department': 'Accounts', 'JobTitle': 'Police officer', 'AccessLevel': 'None', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': True, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': True, 'SettingsAccess': True}, {'EmployeeID': 'd56dfbee-d1a5-4ff5-83dd-96efe2484659', 'EmployeeName': 'Kathryn Elliott', 'Department': 'Stores', 'JobTitle': 'Geochemist', 'AccessLevel': 'Full', 'SalesAccess': False, 'PlanningAccess': True, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': False}, {'EmployeeID': 'bf2c7dc8-c00a-4343-91e0-3785c1854abe', 'EmployeeName': 'Chad Dillon', 'Department': 'Accounts', 'JobTitle': 'Financial manager', 'AccessLevel': 'None', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': True, 'DispatchAccess': True, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': True}, {'EmployeeID': 'ccea9466-238d-4fe6-87eb-cc9225d77a2e', 'EmployeeName': 'Karen Klein', 'Department': 'Sales', 'JobTitle': 'Physiotherapist', 'AccessLevel': 'Full', 'SalesAccess': False, 'PlanningAccess': True, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': True, 'QualityAccess': False, 'DispatchAccess': True, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': False}, {'EmployeeID': '105fe67f-0551-42e4-8856-d25658a02b23', 'Employee ...

# %%
for employee in response.data[:5]:
    print(employee)
# Out:
# {'EmployeeID': 'af2af254-7906-4bcc-9f48-017d0272565e', 'EmployeeName': 'Richard Davis', 'Department': 'Accounts', 'JobTitle': 'Programmer, systems', 'AccessLevel': 'None', 'SalesAccess': True, 'PlanningAccess': True, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': True, 'AccountsAccess': True, 'SettingsAccess': True}
# {'EmployeeID': '1902f73b-5030-4843-b2c2-7222e6937975', 'EmployeeName': 'Bianca Garrett', 'Department': 'Settings', 'JobTitle': 'Physiological scientist', 'AccessLevel': 'Full', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': True, 'MaintenanceAccess': False, 'QualityAccess': True, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': True}
# {'EmployeeID': 'e6215472-f44d-408f-843f-cecc24286407', 'EmployeeName': 'Melinda Thomas', 'Department': 'Dispatch', 'JobTitle': 'Librarian, academic', 'AccessLevel': 'None', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': True, 'StoresAccess': False, 'ProductionAccess': False, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': False}
# {'EmployeeID': 'd629dacb-dccc-4b4a-b310-b2ce96ae03cc', 'EmployeeName': 'Kenneth Lowe V', 'Department': 'Planning', 'JobTitle': 'Doctor, general practice', 'AccessLevel': 'Full', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': True, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': True, 'SettingsAccess': True}
# {'EmployeeID': 'a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04', 'EmployeeName': 'Jessica Johnson', 'Department': 'Sales', 'JobTitle': 'Personal assistant', 'AccessLevel': 'Limited', 'SalesAccess': False, 'PlanningAccess': False, 'PurchaseAccess': False, 'StoresAccess': False, 'ProductionAccess': True, 'MaintenanceAccess': False, 'QualityAccess': False, 'DispatchAccess': False, 'HRAccess': False, 'AccountsAccess': False, 'SettingsAccess': False}

# %%
# !pip install psycopg2

# %%
import psycopg2
from dotenv import load_dotenv
import os

# Load environment variables from .env
load_dotenv()

# Fetch variables
USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")
DBNAME = os.getenv("dbname")

# Connect to the database
try:
    connection = psycopg2.connect(
        user=USER,
        password=PASSWORD,
        host=HOST,
        port=PORT,
        dbname=DBNAME
    )
    print("Connection successful!")
    
    # Create a cursor to execute SQL queries
    cursor = connection.cursor()
    
    # Example query
    cursor.execute("SELECT NOW();")
    result = cursor.fetchone()
    print("Current Time:", result)

    # Close the cursor and connection
    cursor.close()
    connection.close()
    print("Connection closed.")

except Exception as e:
    print(f"Failed to connect: {e}")
