# %%
# !pip install pandas faker

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
import datetime

fake = Faker()

# Number of records to generate
num_records = 500

# --- Sales & NPD Data ---
sales_data = {
    'SalesID': [fake.uuid4() for _ in range(num_records)],
    'CustomerID': [fake.uuid4() for _ in range(num_records)],
    'ProductID': [f'P{random.randint(100, 999)}' for _ in range(num_records)],
    'ProductName': [fake.word().capitalize() + " " + fake.word().capitalize() for _ in range(num_records)],
    'QuotationID': [f'Q{random.randint(1000, 9999)}' if random.random() < 0.8 else None for _ in range(num_records)],
    'SalesOrderDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'InvoiceID': [f'INV{random.randint(10000, 99999)}' for _ in range(num_records)],
    'InvoiceDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'DispatchDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'Quantity': [random.randint(1, 100) for _ in range(num_records)],
    'UnitPrice': [round(random.uniform(10, 1000), 2) for _ in range(num_records)],
    'NPD_Stage': [random.choice(['Idea', 'Prototype', 'Testing', 'Launch', None]) for _ in range(num_records)],
    'NPD_LaunchDate': [fake.date_between(start_date='-1y', end_date='today') if random.random() < 0.2 else None for _ in range(num_records)],
}
sales_df = pd.DataFrame(sales_data)
sales_df.head()
# Out:
#                                 SalesID                            CustomerID  \
# 0  d8fe705e-6958-40b8-975e-72cacfd5fd34  9e80d4eb-f4f8-4025-bd86-4e4a2ffc18b5
# 1  fdeff2b2-c963-42c1-b810-46ca2bd16cea  6750d0e7-b6fd-4eab-bf88-69b46b53ca91
# 2  493cace6-8556-4c77-9bbd-81c43025efb0  577db725-8c36-4729-b111-602fc1d7ab3c
# 3  ac6f6b66-083d-4638-8ee7-28955ead3fde  004043b2-32be-449d-889e-fd59fa55cee2
# 4  1485f54d-ccf0-4b37-ba4c-efd154597afc  c5064f3c-f484-46d4-9872-5531725b8490
#
#   ProductID         ProductName QuotationID SalesOrderDate InvoiceID  \
# 0      P458            Road Son       Q7428     2024-03-28  INV92139
# 1      P897  Relationship Human       Q6866     2024-12-21  INV41085
# 2      P650        Someone Star       Q8393     2025-01-31  INV82094
# 3      P719         Choose Rich       Q7698     2024-09-26  INV55715
# 4      P602            Use Rule       Q4960     2024-06-16  INV31132
#
#   InvoiceDate DispatchDate  Quantity  UnitPrice  NPD_Stage NPD_LaunchDate
# 0  2024-03-23   2025-03-02        13     965.27  Prototype           None
# 1  2025-03-18   2024-05-13        56     642.29       None           None
# 2  2024-07-06   2024-06-04        33     816.87       None           None
# 3  2024-03-25   2024-09-11        33     843.52       None           None
# 4  2025-02-06   2025-02-04        62     570.48    Testing           None

# %%
# --- Planning Data ---
planning_data = {
    'PlanID': [fake.uuid4() for _ in range(num_records)],
    'ProductID': [f'P{random.randint(100, 999)}' for _ in range(num_records)],
    'ForecastDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'ForecastQuantity': [random.randint(50, 500) for _ in range(num_records)],
    'MaterialPlanDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'ProductionScheduleDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
}
planning_df = pd.DataFrame(planning_data)
planning_df.head()
# Out:
#                                  PlanID ProductID ForecastDate  \
# 0  81ae78f0-4a43-4078-8436-cc4a693ba274      P796   2024-10-31
# 1  249513c0-c9d8-47af-8311-bf4e889ac0e6      P181   2024-04-12
# 2  f30e81d5-79aa-472e-920b-41abcbce6e72      P606   2025-03-16
# 3  7ebf2ac6-d29a-466b-aeaa-b7534e7dc8ea      P825   2025-01-03
# 4  c767cbf6-6257-491a-88fd-35517d8a4460      P996   2024-12-23
#
#    ForecastQuantity MaterialPlanDate ProductionScheduleDate
# 0               308       2025-01-08             2024-11-05
# 1               127       2025-03-07             2024-04-11
# 2               273       2025-03-08             2024-05-18
# 3               175       2024-06-24             2024-04-18
# 4               100       2024-10-16             2024-09-11

# %%
# set(sales_df['ProductID']).intersection(planning_df['ProductID'])

# %%
# --- Purchase Data ---
purchase_data = {
    'PurchaseOrderID': [fake.uuid4() for _ in range(num_records)],
    'SupplierID': [fake.uuid4() for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'PurchaseOrderDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'Quantity': [random.randint(100, 1000) for _ in range(num_records)],
    'UnitPrice': [round(random.uniform(5, 500), 2) for _ in range(num_records)],
}
purchase_df = pd.DataFrame(purchase_data)
purchase_df.head()
# Out:
#                         PurchaseOrderID                            SupplierID  \
# 0  3c579356-27c6-4ec7-bbd0-d8d31d3d8e1f  659d3eec-13f7-46a8-9f9d-dc2ea5c4165e
# 1  427f0e65-09a7-4712-bb3e-9101a12a61e9  5a9ba53b-fcbb-4e46-9eff-ee1357e708d9
# 2  9f27f907-475b-4009-b98c-af1ad2983246  25a5ad4d-1cf3-483a-a2ff-9e86e01b4803
# 3  1656fe13-7a10-467e-a1aa-2ea122b18822  5a690d03-ae2e-489f-a262-ef1fb19810b5
# 4  744e91cb-5369-4e16-9d5f-f447fbd0b61b  38cb0c1d-feef-4fc6-9471-ea1f4b0824c3
#
#   MaterialID PurchaseOrderDate  Quantity  UnitPrice
# 0       M980        2025-03-21       507     327.48
# 1       M198        2024-06-27       987     415.40
# 2       M893        2025-03-07       480      49.98
# 3       M576        2024-08-05       260     489.33
# 4       M390        2024-10-14       705     391.84

# %%
# --- Stores Data ---
stores_data = {
    'StoreID': [fake.uuid4() for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'StockLevel': [random.randint(0, 5000) for _ in range(num_records)],
    'MaterialMovementDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'MovementType': [random.choice(['In', 'Out']) for _ in range(num_records)],
    'MovementQuantity': [random.randint(1, 1000) for _ in range(num_records)],
}
stores_df = pd.DataFrame(stores_data)
stores_df.head()
# Out:
#                                 StoreID MaterialID  StockLevel  \
# 0  c5b9be5d-bc10-4262-9708-42a3fa5f2e4f       M780        3354
# 1  8bdae318-344c-4fd1-b610-72aa200e882c       M138        1131
# 2  40c82d1a-d72c-4680-900f-61b29b1c7492       M159         277
# 3  6ad64c48-8740-4623-91a4-82f652c33d4c       M865         130
# 4  e70679f4-8302-4939-92ed-b0982e685ef3       M673         807
#
#   MaterialMovementDate MovementType  MovementQuantity
# 0           2024-10-12          Out               294
# 1           2024-10-23           In               467
# 2           2024-09-01           In               769
# 3           2024-06-06          Out               398
# 4           2024-05-22           In               236

# %%
# set(purchase_df['MaterialID']).intersection(set(stores_df['MaterialID']))

# %%
# --- Production Data ---
production_data = {
    'ProductionID': [fake.uuid4() for _ in range(num_records)],
    'ProductID': [f'P{random.randint(100, 999)}' for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'ProductionDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'JobWorkID': [f'JW{random.randint(1000, 9999)}' if random.random() < 0.5 else None for _ in range(num_records)],
    'RawMaterialConsumption': [random.randint(1, 50) for _ in range(num_records)],
    'ProductionQuantity': [random.randint(1, 200) for _ in range(num_records)]
}
production_df = pd.DataFrame(production_data)
production_df.head()
# Out:
#                            ProductionID ProductID MaterialID ProductionDate  \
# 0  a2dddb54-9f5d-4d4c-bccf-1cd129f422bc      P536       M382     2024-03-27
# 1  91ed0191-9dbe-4742-ab2f-f3b499627f2c      P809       M407     2025-02-21
# 2  54bec732-e8f6-4d87-8acc-adde12e66ca5      P683       M494     2024-12-09
# 3  83145984-2888-4680-972a-ec3b470534ed      P702       M494     2024-05-08
# 4  5cadcab6-4cf3-4044-95de-1056bb934833      P715       M961     2024-05-30
#
#   JobWorkID  RawMaterialConsumption  ProductionQuantity
# 0      None                      10                 174
# 1      None                      40                 157
# 2      None                      16                   4
# 3      None                      40                 135
# 4    JW3624                      41                  17

# %%
# --- Maintenance Data ---
maintenance_data = {
    'MaintenanceID': [fake.uuid4() for _ in range(num_records)],
    'MachineID': [f'MC{random.randint(100, 999)}' for _ in range(num_records)],
    'MaintenanceDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'MaintenanceType': [random.choice(['Preventive', 'Corrective']) for _ in range(num_records)],
    'MaintenanceCost': [round(random.uniform(100, 5000), 2) for _ in range(num_records)],
}
maintenance_df = pd.DataFrame(maintenance_data)
maintenance_df.head()
# Out:
#                           MaintenanceID MachineID MaintenanceDate  \
# 0  90fe7a39-4362-45be-b847-8c175d0300f0     MC446      2024-05-07
# 1  742edd0d-6634-4810-a6b0-ae9345f0ebcf     MC222      2024-07-09
# 2  533d1980-64d7-405d-b4a2-bb75b05b4127     MC563      2024-11-12
# 3  6f600da4-f580-47b6-8ac2-8abd6f808c7b     MC546      2024-06-09
# 4  beefccbb-904e-406a-9fe3-0807f24e9849     MC404      2024-08-03
#
#   MaintenanceType  MaintenanceCost
# 0      Corrective          1746.11
# 1      Preventive          1271.88
# 2      Preventive          4866.47
# 3      Preventive          4912.82
# 4      Corrective          2128.16

# %%
# --- Quality Data ---
quality_data = {
    'QualityID': [fake.uuid4() for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'InspectionDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'InspectionResult': [random.choice(['Pass', 'Fail']) for _ in range(num_records)],
    'ValidationDate': [fake.date_between(start_date='-1y', end_date='today') if random.random() < 0.7 else None for _ in range(num_records)]
}
quality_df = pd.DataFrame(quality_data)
quality_df.head()
# Out:
#                               QualityID MaterialID InspectionDate  \
# 0  3b22f9a7-aa2f-4bbe-96e7-50a4f5f5c221       M346     2024-05-18
# 1  52aa6c25-b04a-4153-85b3-501df6f9fc09       M892     2024-08-09
# 2  2cf571ef-a872-4a84-9bc7-abf9e2150a7f       M850     2024-09-08
# 3  fc377327-8f07-45fd-a1ea-f0b975e358e8       M724     2024-12-22
# 4  8862bb93-db37-47dd-9034-bcf68da9af51       M887     2024-10-14
#
#   InspectionResult ValidationDate
# 0             Fail     2024-10-16
# 1             Pass     2025-02-04
# 2             Pass     2024-12-23
# 3             Pass           None
# 4             Fail     2024-06-21

# %%
# --- Dispatch & Logistics Data ---
dispatch_data = {
    'DispatchID': [fake.uuid4() for _ in range(num_records)],
    'SalesID': [sales_df['SalesID'].sample(n=1).iloc[0] for _ in range(num_records)],
    'TransportPartner': [fake.company() for _ in range(num_records)],
    'DeliveryDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'TrackingNumber': [f'TN{random.randint(100000, 999999)}' for _ in range(num_records)],
}
dispatch_df = pd.DataFrame(dispatch_data)
dispatch_df.head()
# Out:
#                              DispatchID                               SalesID  \
# 0  2cb9467b-783e-458c-af34-1fee926bb699  4adbe0f8-e7fd-48df-a4f2-28b57e278cb1
# 1  0555c221-48be-4738-8a1c-216ad3101eb3  dc515de9-70ae-4c47-b80b-d5a979f5e184
# 2  67dafed7-e88e-4caa-92be-44926239176d  24578744-7fbd-46df-a598-ade630b628e1
# 3  2aec14c8-7ada-4a82-88cd-ea22fab79315  f22a5964-968c-442b-9d08-7c99816b7bb4
# 4  f5b0ab73-e240-4a71-9b56-2ea1481b1ae8  ccb18f8c-6c25-4412-b944-96310b852d77
#
#     TransportPartner DeliveryDate TrackingNumber
# 0         Mccall PLC   2025-03-05       TN730052
# 1          Klein LLC   2024-11-07       TN140185
# 2  Lawrence-Stafford   2025-03-10       TN171248
# 3         Flores Inc   2025-03-09       TN574454
# 4      Mcfarland Inc   2024-05-16       TN450387

# %%
# --- HR & Admin Data ---
hr_data = {
    'EmployeeID': [fake.uuid4() for _ in range(num_records)],
    'EmployeeName': [fake.name() for _ in range(num_records)],
    'HireDate': [fake.date_between(start_date='-5y', end_date='-1y') for _ in range(num_records)],
    'Department': [random.choice(['Sales', 'Planning', 'Purchase', 'Stores', 'Production', 'Maintenance', 'Quality', 'Logistics', 'HR', 'Finance']) for _ in range(num_records)],
    'Salary': [round(random.uniform(30000, 150000), 2) for _ in range(num_records)],
    'PayrollDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
}
hr_df = pd.DataFrame(hr_data)
hr_df.head()
# Out:
#                              EmployeeID      EmployeeName    HireDate  \
# 0  c0da5043-2270-4891-aec1-3a61dbe50d1f      Tammy Taylor  2023-09-25
# 1  29ec23ed-1d70-44c5-aeca-d06e775d14ea  Jennifer Skinner  2020-07-12
# 2  bbc5ef78-c245-477e-9cf6-48c80b54ea5a        Emily Hart  2023-07-14
# 3  e2a61566-bc2f-4d44-830d-d3e0ad721a38  Katherine Riddle  2024-03-11
# 4  89c7bf24-d74e-45d0-a45c-9c6298175483        Tonya Pham  2022-08-31
#
#   Department     Salary PayrollDate
# 0     Stores  147740.91  2024-12-02
# 1   Purchase  123698.06  2024-11-06
# 2     Stores   41618.35  2025-02-22
# 3    Finance   67994.60  2024-08-18
# 4   Planning  123306.58  2024-07-14

# %%
# --- Accounts & Finance Data ---
finance_data = {
    'TransactionID': [fake.uuid4() for _ in range(num_records)],
    'AccountID': [fake.uuid4() for _ in range(num_records)],
    'TransactionDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'TransactionType': [random.choice(['Credit', 'Debit']) for _ in range(num_records)],
    'Amount': [round(random.uniform(500, 100000), 2) for _ in range(num_records)],
    'GST_Compliance': [random.choice([True, False]) for _ in range(num_records)],
}
finance_df = pd.DataFrame(finance_data)
finance_df.head()
# Out:
#                           TransactionID                             AccountID  \
# 0  6c9be132-6468-4245-b755-c97fb8dbc5c5  45d6f1cb-f9e7-41ad-b200-d4e252c894da
# 1  5c76db1d-422c-4d16-a5c3-63a4387e6b20  189ec596-4219-4080-be06-2c5b6500217a
# 2  0f8f263d-1768-402b-be2f-85dfb0866826  7b3ef9cd-b48b-49b2-9722-11582463e4b9
# 3  f91aa09c-f0c3-4b48-a661-b8d16b5d5c43  e23b32a1-3a0c-49dc-b940-beb78c5d9f83
# 4  838515ef-a09c-4ff7-9051-fd8c40ce19e5  d895b7fc-eaee-4867-9433-a3c4bf24504d
#
#   TransactionDate TransactionType    Amount  GST_Compliance
# 0      2024-06-02           Debit  70388.99           False
# 1      2024-09-29           Debit  63972.29           False
# 2      2024-07-08           Debit  20186.75            True
# 3      2024-06-11          Credit  51241.44            True
# 4      2024-08-13          Credit   4265.19           False

# %%
# --- Settings Data ---
settings_data = {
    'SettingID': [fake.uuid4() for _ in range(10)],
    'SettingName': [random.choice(['Tax Rate', 'Discount Policy', 'Currency', 'Payment Terms', 'Return Policy']) for _ in range(10)],
    'SettingValue': [random.choice(['5%', '10%', 'USD', 'Net 30', 'No Returns']) for _ in range(10)],
    'LastUpdated': [fake.date_between(start_date='-1y', end_date='today') for _ in range(10)],
}
settings_df = pd.DataFrame(settings_data)
settings_df.head()
# Out:
#                               SettingID      SettingName SettingValue  \
# 0  fc2268ac-c3d7-43ad-a8e6-fd622f28790e    Payment Terms   No Returns
# 1  92f197d8-800c-4dc0-a646-510043f14c89    Payment Terms       Net 30
# 2  e89d6bd2-46b0-4461-a91f-218c928dd009  Discount Policy          10%
# 3  6b190a14-cd93-45ed-86b0-df5bc62b9ba4  Discount Policy   No Returns
# 4  8d5519c1-acd7-4204-ab05-975c72794714    Return Policy          USD
#
#   LastUpdated
# 0  2024-11-19
# 1  2024-04-13
# 2  2024-10-05
# 3  2024-10-07
# 4  2025-03-04

# %%
# Number of employees
num_employees = 100

# Generate employee data
employee_data = {
    'EmployeeID': [fake.uuid4() for _ in range(num_employees)],
    'EmployeeName': [fake.name() for _ in range(num_employees)],
    'Department': [random.choice(['Sales', 'Planning', 'Purchase', 'Stores', 'Production', 'Maintenance', 'Quality', 'Dispatch', 'HR', 'Accounts', 'Settings']) for _ in range(num_employees)],
    'JobTitle': [fake.job() for _ in range(num_employees)],
    'AccessLevel': [random.choice(['Full', 'Limited', 'None']) for _ in range(num_employees)],
    'SalesAccess': [random.choice([True, False]) if random.choice(['Sales', 'Accounts']) == random.choice(['Sales', 'Accounts']) else False for _ in range(num_employees)],
    'PlanningAccess': [random.choice([True, False]) if random.choice(['Planning', 'Accounts']) == random.choice(['Planning', 'Accounts']) else False for _ in range(num_employees)],
    'PurchaseAccess': [random.choice([True, False]) if random.choice(['Purchase', 'Accounts']) == random.choice(['Purchase', 'Accounts']) else False for _ in range(num_employees)],
    'StoresAccess': [random.choice([True, False]) if random.choice(['Stores', 'Production']) == random.choice(['Stores', 'Production']) else False for _ in range(num_employees)],
    'ProductionAccess': [random.choice([True, False]) if random.choice(['Production', 'Stores']) == random.choice(['Production', 'Stores']) else False for _ in range(num_employees)],
    'MaintenanceAccess': [random.choice([True, False]) if random.choice(['Maintenance', 'Quality']) == random.choice(['Maintenance', 'Quality']) else False for _ in range(num_employees)],
    'QualityAccess': [random.choice([True, False]) if random.choice(['Quality', 'Maintenance']) == random.choice(['Quality', 'Maintenance']) else False for _ in range(num_employees)],
    'DispatchAccess': [random.choice([True, False]) if random.choice(['Dispatch', 'Sales']) == random.choice(['Dispatch', 'Sales']) else False for _ in range(num_employees)],
    'HRAccess': [random.choice([True, False]) if random.choice(['HR', 'Accounts', 'Settings']) == random.choice(['HR', 'Accounts', 'Settings']) else False for _ in range(num_employees)],
    'AccountsAccess': [random.choice([True, False]) if random.choice(['Accounts', 'Settings']) == random.choice(['Accounts', 'Settings']) else False for _ in range(num_employees)],
    'SettingsAccess': [random.choice([True, False]) if random.choice(['Settings', 'Accounts']) == random.choice(['Settings', 'Accounts']) else False for _ in range(num_employees)],
}

employee_df = pd.DataFrame(employee_data)
employee_df.head()
# Out:
#                              EmployeeID     EmployeeName Department  \
# 0  af2af254-7906-4bcc-9f48-017d0272565e    Richard Davis   Accounts
# 1  1902f73b-5030-4843-b2c2-7222e6937975   Bianca Garrett   Settings
# 2  e6215472-f44d-408f-843f-cecc24286407   Melinda Thomas   Dispatch
# 3  d629dacb-dccc-4b4a-b310-b2ce96ae03cc   Kenneth Lowe V   Planning
# 4  a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04  Jessica Johnson      Sales
#
#                    JobTitle AccessLevel  SalesAccess  PlanningAccess  \
# 0       Programmer, systems        None         True            True
# 1   Physiological scientist        Full        False           False
# 2       Librarian, academic        None        False           False
# 3  Doctor, general practice        Full        False           False
# 4        Personal assistant     Limited        False           False
#
#    PurchaseAccess  StoresAccess  ProductionAccess  MaintenanceAccess  \
# 0           False         False             False              False
# 1           False         False              True              False
# 2            True         False             False              False
# 3           False         False              True              False
# 4           False         False              True              False
#
#    QualityAccess  DispatchAccess  HRAccess  AccountsAccess  SettingsAccess
# 0          False           False      True            True            True
# 1           True           False     False           False            True
# 2          False           False     False           False           False
# 3          False           False     False            True            True
# 4          False           False     False           False           False

# %%
# Save to CSV files
sales_df.to_csv('../db/sales_data.csv', index=False)
planning_df.to_csv('../db/planning_data.csv', index=False)
purchase_df.to_csv('../db/purchase_data.csv', index=False)
stores_df.to_csv('../db/stores_data.csv', index=False)
production_df.to_csv('../db/production_data.csv', index=False)
maintenance_df.to_csv('../db/maintenance_data.csv', index=False)
quality_df.to_csv('../db/quality_data.csv', index=False)
dispatch_df.to_csv('../db/dispatch_data.csv', index=False)
hr_df.to_csv('../db/hr_data.csv', index=False)
finance_df.to_csv('../db/finance_data.csv', index=False)
settings_df.to_csv('../db/settings_data.csv', index=False)
employee_df.to_csv('../db/employees_data.csv', index=False)

print("Sample data generated and saved successfully.")
# Out:
# Sample data generated and saved successfully.

# %%
import os
import glob
import pymongo
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

# Connect to MongoDB
client = pymongo.MongoClient(os.environ['MONGO_URI'])
db = client["hack_ai_thon"]

# List of CSV files and their corresponding MongoDB collections
csv_files = {
    "sales_data.csv": "Sales_NPD",
    "planning_data.csv": "Planning",
    "purchase_data.csv": "Purchase",
    "stores_data.csv": "Stores",
    "production_data.csv": "Production",
    "maintenance_data.csv": "Maintenance",
    "quality_data.csv": "Quality",
    "dispatch_data.csv": "Dispatch_Logistics",
    "hr_data.csv": "HR_Admin",
    "finance_data.csv": "Accounts_Finance",
    "settings_data.csv": "Settings",
    "employees_data.csv" : "Employees"
}

# %%
# Function to upload CSV data to MongoDB
def upload_to_mongodb(csv_filename, collection_name):
    collection = db[collection_name] 
    df = pd.read_csv(csv_filename)
    data = df.to_dict(orient="records")
    collection.insert_many(data)
    print(f"Uploaded {len(data)} records to {collection_name}")

for path in glob.glob("db/*.csv"):
    upload_to_mongodb(path, csv_files[path.split('\\')[-1]])
print("All data uploaded successfully to MongoDB.")
# Out:
# Uploaded 500 records to Dispatch_Logistics
# Uploaded 500 records to Accounts_Finance
# Uploaded 500 records to HR_Admin
# Uploaded 500 records to Maintenance
# Uploaded 500 records to Planning
# Uploaded 500 records to Production
# Uploaded 500 records to Purchase
# Uploaded 500 records to Quality
# Uploaded 500 records to Sales_NPD
# Uploaded 10 records to Settings
# Uploaded 500 records to Stores
# All data uploaded successfully to MongoDB.

# %%
# !pip install nltk pdfplumber faiss-cpu sentence-transformers

# %%
import re
import faiss
import pdfplumber
from nltk.stem import WordNetLemmatizer
from langchain.vectorstores import FAISS
from sentence_transformers import SentenceTransformer
from langchain.schema import Document
from langchain.docstore import InMemoryDocstore
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from langchain.text_splitter import SentenceTransformersTokenTextSplitter

model = SentenceTransformer('all-MiniLM-L6-v2')
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in ENGLISH_STOP_WORDS]
    return ' '.join(tokens)


def gen_embeddings(texts):
    return model.encode(texts)

# %%
pdf = pdfplumber.open("../db/Sample-Code-of-Conduct-for-Small-and-Medium-Enterprises.pdf")

text = ""
for page in pdf.pages:
    text += page.extract_text() + "\n"

text_splitter = SentenceTransformersTokenTextSplitter(chunk_overlap=50, tokens_per_chunk=384)
text_chunks = text_splitter.split_text(text)

embeddings = gen_embeddings(text_chunks)
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

documents = [
    Document(page_content=text)
    for text in text_chunks
]
docstore_dict = {str(idx): doc for idx, doc in enumerate(documents)}
docstore = InMemoryDocstore(docstore_dict)
index_to_docstore_id = {i: str(i) for i in range(len(documents))}

vector_store = FAISS(embedding_function=gen_embeddings, index=index, docstore=docstore, index_to_docstore_id=index_to_docstore_id)
retriever = vector_store.as_retriever()
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
import pandas as pd

employee_df = pd.read_csv("../db/employees_data.csv")
employee_df.head()
# Out:
#                              EmployeeID     EmployeeName Department  \
# 0  af2af254-7906-4bcc-9f48-017d0272565e    Richard Davis   Accounts
# 1  1902f73b-5030-4843-b2c2-7222e6937975   Bianca Garrett   Settings
# 2  e6215472-f44d-408f-843f-cecc24286407   Melinda Thomas   Dispatch
# 3  d629dacb-dccc-4b4a-b310-b2ce96ae03cc   Kenneth Lowe V   Planning
# 4  a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04  Jessica Johnson      Sales
#
#                    JobTitle AccessLevel  SalesAccess  PlanningAccess  \
# 0       Programmer, systems         NaN         True            True
# 1   Physiological scientist        Full        False           False
# 2       Librarian, academic         NaN        False           False
# 3  Doctor, general practice        Full        False           False
# 4        Personal assistant     Limited        False           False
#
#    PurchaseAccess  StoresAccess  ProductionAccess  MaintenanceAccess  \
# 0           False         False             False              False
# 1           False         False              True              False
# 2            True         False             False              False
# 3           False         False              True              False
# 4           False         False              True              False
#
#    QualityAccess  DispatchAccess  HRAccess  AccountsAccess  SettingsAccess
# 0          False           False      True            True            True
# 1           True           False     False           False            True
# 2          False           False     False           False           False
# 3          False           False     False            True            True
# 4          False           False     False           False           False

# %%
import random

employees_split = employee_df['EmployeeName'].str.split()
emails = [".".join(split[:2]).lower() + "@gmail.com" for split in employees_split]
passwords = [str(random.randrange(100000, 999999)) for _ in range(len(employee_df))]
employee_df['EmployeeEmail'] = emails
employee_df['EmployeePassword'] = passwords

# %%
employee_df.head()
# Out:
#                              EmployeeID     EmployeeName Department  \
# 0  af2af254-7906-4bcc-9f48-017d0272565e    Richard Davis   Accounts
# 1  1902f73b-5030-4843-b2c2-7222e6937975   Bianca Garrett   Settings
# 2  e6215472-f44d-408f-843f-cecc24286407   Melinda Thomas   Dispatch
# 3  d629dacb-dccc-4b4a-b310-b2ce96ae03cc   Kenneth Lowe V   Planning
# 4  a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04  Jessica Johnson      Sales
#
#                    JobTitle AccessLevel  SalesAccess  PlanningAccess  \
# 0       Programmer, systems         NaN         True            True
# 1   Physiological scientist        Full        False           False
# 2       Librarian, academic         NaN        False           False
# 3  Doctor, general practice        Full        False           False
# 4        Personal assistant     Limited        False           False
#
#    PurchaseAccess  StoresAccess  ProductionAccess  MaintenanceAccess  \
# 0           False         False             False              False
# 1           False         False              True              False
# 2            True         False             False              False
# 3           False         False              True              False
# 4           False         False              True              False
#
#    QualityAccess  DispatchAccess  HRAccess  AccountsAccess  SettingsAccess  \
# 0          False           False      True            True            True
# 1           True           False     False           False            True
# 2          False           False     False           False           False
# 3          False           False     False            True            True
# 4          False           False     False           False           False
#
#                EmployeeEmail EmployeePassword
# 0    richard.davis@gmail.com           873845
# 1   bianca.garrett@gmail.com           932197
# 2   melinda.thomas@gmail.com           783217
# 3     kenneth.lowe@gmail.com           957571
# 4  jessica.johnson@gmail.com           401237

# %%
employee_df.to_csv("../db/employees_data_with_password.csv", index=False)

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient

load_dotenv()

mongo_client = MongoClient(os.environ.get("MONGO_URI"))
mongo_db = mongo_client['hack_ai_thon']
collection = mongo_db['Employees']

# %%
import os

os.environ['SUPABASE_URL'] = 'postgresql://postgres.chduybdjpvedaveezdbf:Lintomon2003*@aws-0-ap-southeast-1.pooler.supabase.com:6543/postgres'

# %%
os.environ['SUPABASE_URL']
# Out:
# 'postgresql://postgres.chduybdjpvedaveezdbf:Lintomon2003*@aws-0-ap-southeast-1.pooler.supabase.com:6543/postgres'

# %%
import requests

BASE_URL = "http://127.0.0.1:5000"

def create_user(user):
    url = f"{BASE_URL}/sign-up"
    response = requests.post(url, json=user)
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": f"Failed to create user: {response.text}"}


employee_df.fillna(value='None', inplace=True)
for idx, emp in employee_df.iterrows():
    user_response = create_user(emp.to_dict())
    print(user_response)
# Out:
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': None, 'message': 'User with this email already exists'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:22.713070', 'ExpiresAt': '2025-03-24 05:19:22.713070', 'SessionToken': '0818c60823e53c9ec21fadda97c21dac77b05db70657b7249782a9a01eea9f8b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:22.981213', 'ExpiresAt': '2025-03-24 05:19:22.981213', 'SessionToken': 'fcf4e12fd6d8596ed30a258b3d8924bf5a386847503accd28d2347e21dca9344'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:23.261295', 'ExpiresAt': '2025-03-24 05:19:23.261295', 'SessionToken': '179a01d016aa2b753209c4208cdabebac748c5afba3bcf980e1e91e2528e943b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:23.531120', 'ExpiresAt': '2025-03-24 05:19:23.531120', 'SessionToken': '2ae1c1e07094b27e849319f66cb925590c5063a243eb0a4a89566dd452b49df8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:23.801310', 'ExpiresAt': '2025-03-24 05:19:23.801310', 'SessionToken': '5146168c165175a2330122861a292309cdd1759c2f3b100f9746f7e52e841260'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:24.090529', 'ExpiresAt': '2025-03-24 05:19:24.090529', 'SessionToken': '08ed41538289aca3673194fba72add22ea73f14becf43c41c5ea802c2e715e27'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:24.357186', 'ExpiresAt': '2025-03-24 05:19:24.357186', 'SessionToken': 'ea2dcc0ccee6c0da11c1bd2e7d9c431956797554f53cc2493abfe6f3f823222a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:24.625128', 'ExpiresAt': '2025-03-24 05:19:24.625128', 'SessionToken': 'fc166ed3db675fe5426b266e8555d9d0335d9e4aeee33cb2770b10287e4c465c'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:24.892760', 'ExpiresAt': '2025-03-24 05:19:24.892760', 'SessionToken': '658c1fab15a745829b0e7db9c75de9dd1993ebf214ff37db7c32c81875aed7a0'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:25.162744', 'ExpiresAt': '2025-03-24 05:19:25.162744', 'SessionToken': '6da64596e9a191c4961970c1fbc53b49914cc38822bd9a0842cbcc8ed16a272e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:25.430528', 'ExpiresAt': '2025-03-24 05:19:25.430528', 'SessionToken': '715101405769696e08f889c96631df63cb32c68c343171a9e3d987ee36a6a6d8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:25.700883', 'ExpiresAt': '2025-03-24 05:19:25.700883', 'SessionToken': '2cd5da9ab20d586bf959e077b120f58bf5224d7c502f3268a9a00a0a72c5ef60'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:25.971043', 'ExpiresAt': '2025-03-24 05:19:25.971043', 'SessionToken': 'c6be5ce0052ef14fc2ec448e072fcc007197d0f864c4aefcf922b1dde9c5bc8b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:26.247072', 'ExpiresAt': '2025-03-24 05:19:26.247072', 'SessionToken': '82aff7294db87d937ed8389a5a193ca8d38cb1a8bacf141436fb6e3708c603fe'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:26.515727', 'ExpiresAt': '2025-03-24 05:19:26.515727', 'SessionToken': '159d06ebdb7d97e3306f4a9b54b1e1b5c4277f06af14f18f8e516f94129c3829'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:26.784854', 'ExpiresAt': '2025-03-24 05:19:26.784854', 'SessionToken': 'a980612ed00aa264494f7a0867c9b9abc956412e634ebb58df7ee434045504ff'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:27.051838', 'ExpiresAt': '2025-03-24 05:19:27.051838', 'SessionToken': 'aede717fa6d5ce6980940a378418a39701d091871b31377cf5e719475ce01666'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:27.320658', 'ExpiresAt': '2025-03-24 05:19:27.320658', 'SessionToken': '63d70b4846819d9abd0f6189df42753aa4f4f0be1a016ad2b354a48ef1729ecd'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:27.593120', 'ExpiresAt': '2025-03-24 05:19:27.593120', 'SessionToken': '6814122e97209d8445140cb292617c917cebc1fe97c93d9d8130360e09f54c50'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:27.861177', 'ExpiresAt': '2025-03-24 05:19:27.861177', 'SessionToken': '60a915461c5429ecbf6737426e6f15a51ce878458a24c7d6aff2b50bf19d8397'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:28.139719', 'ExpiresAt': '2025-03-24 05:19:28.139719', 'SessionToken': '0b06170eab6a18d0e3e05d2e171acaa613f729d32594b04bfff29c879b39e7aa'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:28.407145', 'ExpiresAt': '2025-03-24 05:19:28.407145', 'SessionToken': '40f8e6aabf99be54dce33bac85e82ee609d0762a387892c6f95b5d40aca3cbb2'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:28.679616', 'ExpiresAt': '2025-03-24 05:19:28.679616', 'SessionToken': '74a1466140becd847928a36648795b7a92d162242f5e5a517e794eb269345ec5'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:28.945446', 'ExpiresAt': '2025-03-24 05:19:28.945446', 'SessionToken': 'e3c49c93e5ee743796858cbdd557d926c1ad1ff4262fe4d03bca3aa207e52e3e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:29.225770', 'ExpiresAt': '2025-03-24 05:19:29.225770', 'SessionToken': '0eea4e558e13e07605732b66d5712d32701f5b36062817902985f2e81dbfd727'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:29.493435', 'ExpiresAt': '2025-03-24 05:19:29.493435', 'SessionToken': 'cadfdad256ea81020e418246145dda5f098e69c457973ab8cbfd6688b1b76ded'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:29.762325', 'ExpiresAt': '2025-03-24 05:19:29.762325', 'SessionToken': '79379eddacd518a9668a0cc5c1b48d66e9658ee13d28b81fe324ff673b9c7090'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:30.030792', 'ExpiresAt': '2025-03-24 05:19:30.030792', 'SessionToken': 'd9f7593e74a3495d16f2e5bb8033d424acc718ab90b1717d39cf73ca621fde3f'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:30.310969', 'ExpiresAt': '2025-03-24 05:19:30.310969', 'SessionToken': '6ced82684a8a8c4cd6465d296a27bc09142b6c12f30d14074f24ed0558c61636'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:30.582104', 'ExpiresAt': '2025-03-24 05:19:30.582104', 'SessionToken': '62fddc5f5240ed66f6a4a8d8c790f5c9e1bd0b3f9993692b815de0e9c3a20222'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:30.871869', 'ExpiresAt': '2025-03-24 05:19:30.871869', 'SessionToken': '8318008d9fb676409ac6a4971d0bfdef4179207f85ce92cbd65319a2ee5bcbf8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:31.141697', 'ExpiresAt': '2025-03-24 05:19:31.141697', 'SessionToken': '5152059c8e59767c7929108d81534d502dea82f316c782c52de9ddc79438433c'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:31.407369', 'ExpiresAt': '2025-03-24 05:19:31.407369', 'SessionToken': '9e7981530c13ecfe6b9a36f9489954343fdc07d75cb0babc626f50e80680469e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:31.696196', 'ExpiresAt': '2025-03-24 05:19:31.696196', 'SessionToken': '805640cadb48d698e0f6e292675d9077cf0d824b90348985b6bd65d0d1e1bd40'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:31.966182', 'ExpiresAt': '2025-03-24 05:19:31.966182', 'SessionToken': 'b9769dcf24c74a7b8c4bd22859c47b20eda326c46f8b19036a8c896dc93543f6'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:32.235282', 'ExpiresAt': '2025-03-24 05:19:32.235282', 'SessionToken': '29273f917d2ced03bbdc2e830d1cb4e5f3f6ce50452e2d52a5d0595f3b1dc9c7'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:32.512688', 'ExpiresAt': '2025-03-24 05:19:32.512688', 'SessionToken': 'f90ce97690b12a2a50f670d4d94c8afef8c0f2c5ef669ab94c5a6a9a4e418376'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:32.783565', 'ExpiresAt': '2025-03-24 05:19:32.783565', 'SessionToken': 'aae1c2530e894dd899e9b490cd4837dfa59a48f7475faf239c372ab4ed5a9696'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:33.058166', 'ExpiresAt': '2025-03-24 05:19:33.058166', 'SessionToken': '27970f9155194d64e9f06b6bbca2e40646c08352b5acfbb733005216899ab5ac'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:33.332072', 'ExpiresAt': '2025-03-24 05:19:33.332072', 'SessionToken': '687783d352daf0cfc32728cf7f55662700751f72b7573f347ce52fe26fbee477'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:33.609155', 'ExpiresAt': '2025-03-24 05:19:33.609155', 'SessionToken': '7cff04ebe307ca6beef8737aa808c31ac74a9aec4b9f6d2a98c1489314f2a8f2'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:33.877220', 'ExpiresAt': '2025-03-24 05:19:33.877220', 'SessionToken': 'b1c2909dd3cca5aa2214aaa94da35d6af64a8d8d65af232a02cdc699e471f751'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:34.145028', 'ExpiresAt': '2025-03-24 05:19:34.145028', 'SessionToken': 'a1aae10aeb0e3d0b34f24e1fff81d97c38c141904fd9eb42ed0e681f79301878'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:34.412374', 'ExpiresAt': '2025-03-24 05:19:34.412374', 'SessionToken': 'a8cc4c3a11723ce117fafdb962afc89a94847124a20cf759382bbd2b6913146b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:34.681378', 'ExpiresAt': '2025-03-24 05:19:34.681378', 'SessionToken': '62cef4fcb345f26e2f7bde579f3749413fd1d6e66a9bd00be7ac0dfe1c54f546'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:34.949758', 'ExpiresAt': '2025-03-24 05:19:34.949758', 'SessionToken': '267bf93c988df6edd49044397340b22b6594bacefe218b7bbedfc58aaff8de25'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:35.217212', 'ExpiresAt': '2025-03-24 05:19:35.217212', 'SessionToken': '37603299c1093998f962750d310733d661838aed3dd9fb1f6f7a6ea24b738058'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:35.486399', 'ExpiresAt': '2025-03-24 05:19:35.486399', 'SessionToken': 'ad6a7ede09b3d896f85f90ebe4cfc0f0efd4526e3b0a801a6f617d0eaad9ad34'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:35.754098', 'ExpiresAt': '2025-03-24 05:19:35.754098', 'SessionToken': '2bf6be0bfa6b227f9d39677ab264e27d11b57162cf0b3b7a7f04f43b6e48a5cb'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:36.022521', 'ExpiresAt': '2025-03-24 05:19:36.022521', 'SessionToken': '1730e4bc33ab5dafcd6992c67eb2f01853266f90e0c521cea6cccca45adfba47'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:36.293801', 'ExpiresAt': '2025-03-24 05:19:36.293801', 'SessionToken': '06f6cdd09d89986b8854fdaa5fc4c48bb2f90dc9c9c8fc131f4f04290ff9d759'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:36.561159', 'ExpiresAt': '2025-03-24 05:19:36.561159', 'SessionToken': '73c5c9ebba513665c5bd52926f60d9a797225c28911cf8af4670507b8878c0be'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:36.829545', 'ExpiresAt': '2025-03-24 05:19:36.829545', 'SessionToken': '4eca314c068fbd5e603c1dfa2fb5df6d215c668498a17c78599500cf680607cf'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:37.096343', 'ExpiresAt': '2025-03-24 05:19:37.096343', 'SessionToken': 'a7661261d9e10d4955ee1e78f9e74e59d40bf7bba91a257b70f66628f1855521'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:37.365881', 'ExpiresAt': '2025-03-24 05:19:37.365881', 'SessionToken': 'a49395cbd0b03ada7af39731d08386d2d90cf47f5309235d49ddb182dca90150'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:37.636357', 'ExpiresAt': '2025-03-24 05:19:37.636357', 'SessionToken': '78be28db127385e28c6d47f5d1d2966cd895fb674bba3d69f8f80a7af3c700d1'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:37.904544', 'ExpiresAt': '2025-03-24 05:19:37.904544', 'SessionToken': 'b0787a62273bead8049f3f5a619cd4f687520e32199f3fc55f6194d6cd1a0588'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:38.182122', 'ExpiresAt': '2025-03-24 05:19:38.182122', 'SessionToken': '9046b63fb4ba03354ce934ecc1c981eb15f5704d8a2a0b3a511f3eb971eea39e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:38.461077', 'ExpiresAt': '2025-03-24 05:19:38.461077', 'SessionToken': '8e3067e65234db3852a0140a32c25b533c4166d4c4e7fbdea8ae0ab17dfbd13f'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:38.727191', 'ExpiresAt': '2025-03-24 05:19:38.727191', 'SessionToken': 'b74ace0fc80c0a80642994125954d2f1039b2016e8da6114bf8f40bf7acf7a27'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:38.995533', 'ExpiresAt': '2025-03-24 05:19:38.995533', 'SessionToken': '6aed475b14095d728f669b92a8794c0776f38560a0d67de5d9d015ced56ec7eb'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:39.262229', 'ExpiresAt': '2025-03-24 05:19:39.262229', 'SessionToken': '4cb2cc0a22a4d74a50cee756d6555d92ec4892a683a8d4e04752a7d1d71e3f5e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:39.530490', 'ExpiresAt': '2025-03-24 05:19:39.530490', 'SessionToken': '3f90ae2482e8e6f53632a1dedfdc1edda80dee94511f74afedba0a767ae33a98'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:39.802896', 'ExpiresAt': '2025-03-24 05:19:39.802896', 'SessionToken': 'e42aa2040ef0a1cfe419bccd41c454cd8609e1e20e15cb360c52c4be9d97c9f8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:40.080490', 'ExpiresAt': '2025-03-24 05:19:40.080490', 'SessionToken': 'e3023b4a8eb235a32c46d224430837d5a103a84851b340c369ad9f3815adb87d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:40.348410', 'ExpiresAt': '2025-03-24 05:19:40.348410', 'SessionToken': 'a050eec2cd347d5b40139c5ef30aabd1cf36e90a201ffa22660f00863e6637c1'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:40.634565', 'ExpiresAt': '2025-03-24 05:19:40.634565', 'SessionToken': '3f7ba91574b0c70a20c150ba0a9ffdf50b39ff0659009dd2d876344f62b722ad'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:40.907157', 'ExpiresAt': '2025-03-24 05:19:40.907157', 'SessionToken': 'aa245b3212bd5214b8bd4884dd615d0b9d6c061b85599d622452ed6e43a60507'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:41.187037', 'ExpiresAt': '2025-03-24 05:19:41.187037', 'SessionToken': 'ae6f9e0799dfbf215c5099696cc90a1caea607ff451f950959a4cc3ec7cbea2d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:41.477065', 'ExpiresAt': '2025-03-24 05:19:41.477065', 'SessionToken': '5164181745a8da1ab1ff42c7cff159305a0373a12121df987f0074998c7f2317'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:41.760343', 'ExpiresAt': '2025-03-24 05:19:41.760343', 'SessionToken': '3cc79865b102d36f9caa5a886618a3fb076fedc06c34f5d90093eaa35c8e547e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:42.040341', 'ExpiresAt': '2025-03-24 05:19:42.040341', 'SessionToken': 'be00fe7de5b7efd7b318554a70b6fceb5f5ec3d1188447586178fd17cf6e3d59'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:42.310809', 'ExpiresAt': '2025-03-24 05:19:42.310809', 'SessionToken': 'ddedcd9f2b76c4507725585fbeb1515acda2794ccf99f94089afeefa7f657c1a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:42.580953', 'ExpiresAt': '2025-03-24 05:19:42.580953', 'SessionToken': '4c99c7cc51f9c8cf0ae7e744c0d44b2e4334ae5fd39f690ba486ba1dee0116e8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:42.850361', 'ExpiresAt': '2025-03-24 05:19:42.850361', 'SessionToken': 'a3bbcd39003f9f976646baa6602658f679f431329b6ed3f2ebdf15d2eba9648b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:43.115556', 'ExpiresAt': '2025-03-24 05:19:43.115556', 'SessionToken': '8729c75f6b2d6d297950649cc6b3dc900b6a5a1a66f76c17c733c7b1b3afc15f'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:43.388017', 'ExpiresAt': '2025-03-24 05:19:43.388017', 'SessionToken': '0060dce4a7dcba74dbdfc8db21fcd1a95e487455aab21f20b33707f1a14287cd'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:43.671471', 'ExpiresAt': '2025-03-24 05:19:43.671471', 'SessionToken': '955ea13c345854932458d632f31ff60e5ad93653f67a77b2496632f9e28c45d3'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:43.938396', 'ExpiresAt': '2025-03-24 05:19:43.938396', 'SessionToken': '1b2f88ab2c15e16527ae31d2417a4268824d6354b3fa53769d5bc99a9783fae6'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:44.209676', 'ExpiresAt': '2025-03-24 05:19:44.209676', 'SessionToken': '04622b134c9c980e030840c4d1c62c9b2c7c0d871ff82ed063de36773a26fac1'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:44.477080', 'ExpiresAt': '2025-03-24 05:19:44.477080', 'SessionToken': 'e8b56edfe3370309d34d6d329741e5f1c3a6d3f82066c4c8eef23177987db648'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:44.762943', 'ExpiresAt': '2025-03-24 05:19:44.762943', 'SessionToken': '973d4d5b9a85c9443f1d7432dca1b3cf039b85437215040c33f0a4b587385229'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:45.035662', 'ExpiresAt': '2025-03-24 05:19:45.035662', 'SessionToken': '1c9903d8067ed64222d3175730f96a475c51bb8ce5fed1bd66df50ead2c77e4d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:45.303186', 'ExpiresAt': '2025-03-24 05:19:45.303186', 'SessionToken': '9b8341bf6b2e9b9bea159509017c898eaff8c2c6c3e3ef415d02d24d4180e2dc'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'CreatedAt': '2025-03-23 05:19:45.571162', 'ExpiresAt': '2025-03-24 05:19:45.571162', 'SessionToken': '85c4a65d55379097c3cad7e2143b002f6b078867b107220b8b4bebd8daf21ed5'}}, 'message': 'Session created successfully'}
