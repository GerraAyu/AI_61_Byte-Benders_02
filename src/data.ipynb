# %%
# !pip install pandas faker

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
import datetime

fake = Faker()

# Number of records to generate
num_records = 500

# --- Sales & NPD Data ---
sales_data = {
    'SalesID': [fake.uuid4() for _ in range(num_records)],
    'CustomerID': [fake.uuid4() for _ in range(num_records)],
    'ProductID': [f'P{random.randint(100, 999)}' for _ in range(num_records)],
    'ProductName': [fake.word().capitalize() + " " + fake.word().capitalize() for _ in range(num_records)],
    'QuotationID': [f'Q{random.randint(1000, 9999)}' if random.random() < 0.8 else None for _ in range(num_records)],
    'SalesOrderDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'InvoiceID': [f'INV{random.randint(10000, 99999)}' for _ in range(num_records)],
    'InvoiceDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'DispatchDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'Quantity': [random.randint(1, 100) for _ in range(num_records)],
    'UnitPrice': [round(random.uniform(10, 1000), 2) for _ in range(num_records)],
    'NPD_Stage': [random.choice(['Idea', 'Prototype', 'Testing', 'Launch', None]) for _ in range(num_records)],
    'NPD_LaunchDate': [fake.date_between(start_date='-1y', end_date='today') if random.random() < 0.2 else None for _ in range(num_records)],
}
sales_df = pd.DataFrame(sales_data)
sales_df.head()
# Out:
#                                 SalesID                            CustomerID  \
# 0  d8fe705e-6958-40b8-975e-72cacfd5fd34  9e80d4eb-f4f8-4025-bd86-4e4a2ffc18b5
# 1  fdeff2b2-c963-42c1-b810-46ca2bd16cea  6750d0e7-b6fd-4eab-bf88-69b46b53ca91
# 2  493cace6-8556-4c77-9bbd-81c43025efb0  577db725-8c36-4729-b111-602fc1d7ab3c
# 3  ac6f6b66-083d-4638-8ee7-28955ead3fde  004043b2-32be-449d-889e-fd59fa55cee2
# 4  1485f54d-ccf0-4b37-ba4c-efd154597afc  c5064f3c-f484-46d4-9872-5531725b8490
#
#   ProductID         ProductName QuotationID SalesOrderDate InvoiceID  \
# 0      P458            Road Son       Q7428     2024-03-28  INV92139
# 1      P897  Relationship Human       Q6866     2024-12-21  INV41085
# 2      P650        Someone Star       Q8393     2025-01-31  INV82094
# 3      P719         Choose Rich       Q7698     2024-09-26  INV55715
# 4      P602            Use Rule       Q4960     2024-06-16  INV31132
#
#   InvoiceDate DispatchDate  Quantity  UnitPrice  NPD_Stage NPD_LaunchDate
# 0  2024-03-23   2025-03-02        13     965.27  Prototype           None
# 1  2025-03-18   2024-05-13        56     642.29       None           None
# 2  2024-07-06   2024-06-04        33     816.87       None           None
# 3  2024-03-25   2024-09-11        33     843.52       None           None
# 4  2025-02-06   2025-02-04        62     570.48    Testing           None

# %%
# --- Planning Data ---
planning_data = {
    'PlanID': [fake.uuid4() for _ in range(num_records)],
    'ProductID': [f'P{random.randint(100, 999)}' for _ in range(num_records)],
    'ForecastDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'ForecastQuantity': [random.randint(50, 500) for _ in range(num_records)],
    'MaterialPlanDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'ProductionScheduleDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
}
planning_df = pd.DataFrame(planning_data)
planning_df.head()
# Out:
#                                  PlanID ProductID ForecastDate  \
# 0  81ae78f0-4a43-4078-8436-cc4a693ba274      P796   2024-10-31
# 1  249513c0-c9d8-47af-8311-bf4e889ac0e6      P181   2024-04-12
# 2  f30e81d5-79aa-472e-920b-41abcbce6e72      P606   2025-03-16
# 3  7ebf2ac6-d29a-466b-aeaa-b7534e7dc8ea      P825   2025-01-03
# 4  c767cbf6-6257-491a-88fd-35517d8a4460      P996   2024-12-23
#
#    ForecastQuantity MaterialPlanDate ProductionScheduleDate
# 0               308       2025-01-08             2024-11-05
# 1               127       2025-03-07             2024-04-11
# 2               273       2025-03-08             2024-05-18
# 3               175       2024-06-24             2024-04-18
# 4               100       2024-10-16             2024-09-11

# %%
# set(sales_df['ProductID']).intersection(planning_df['ProductID'])

# %%
# --- Purchase Data ---
purchase_data = {
    'PurchaseOrderID': [fake.uuid4() for _ in range(num_records)],
    'SupplierID': [fake.uuid4() for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'PurchaseOrderDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'Quantity': [random.randint(100, 1000) for _ in range(num_records)],
    'UnitPrice': [round(random.uniform(5, 500), 2) for _ in range(num_records)],
}
purchase_df = pd.DataFrame(purchase_data)
purchase_df.head()
# Out:
#                         PurchaseOrderID                            SupplierID  \
# 0  3c579356-27c6-4ec7-bbd0-d8d31d3d8e1f  659d3eec-13f7-46a8-9f9d-dc2ea5c4165e
# 1  427f0e65-09a7-4712-bb3e-9101a12a61e9  5a9ba53b-fcbb-4e46-9eff-ee1357e708d9
# 2  9f27f907-475b-4009-b98c-af1ad2983246  25a5ad4d-1cf3-483a-a2ff-9e86e01b4803
# 3  1656fe13-7a10-467e-a1aa-2ea122b18822  5a690d03-ae2e-489f-a262-ef1fb19810b5
# 4  744e91cb-5369-4e16-9d5f-f447fbd0b61b  38cb0c1d-feef-4fc6-9471-ea1f4b0824c3
#
#   MaterialID PurchaseOrderDate  Quantity  UnitPrice
# 0       M980        2025-03-21       507     327.48
# 1       M198        2024-06-27       987     415.40
# 2       M893        2025-03-07       480      49.98
# 3       M576        2024-08-05       260     489.33
# 4       M390        2024-10-14       705     391.84

# %%
# --- Stores Data ---
stores_data = {
    'StoreID': [fake.uuid4() for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'StockLevel': [random.randint(0, 5000) for _ in range(num_records)],
    'MaterialMovementDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'MovementType': [random.choice(['In', 'Out']) for _ in range(num_records)],
    'MovementQuantity': [random.randint(1, 1000) for _ in range(num_records)],
}
stores_df = pd.DataFrame(stores_data)
stores_df.head()
# Out:
#                                 StoreID MaterialID  StockLevel  \
# 0  c5b9be5d-bc10-4262-9708-42a3fa5f2e4f       M780        3354
# 1  8bdae318-344c-4fd1-b610-72aa200e882c       M138        1131
# 2  40c82d1a-d72c-4680-900f-61b29b1c7492       M159         277
# 3  6ad64c48-8740-4623-91a4-82f652c33d4c       M865         130
# 4  e70679f4-8302-4939-92ed-b0982e685ef3       M673         807
#
#   MaterialMovementDate MovementType  MovementQuantity
# 0           2024-10-12          Out               294
# 1           2024-10-23           In               467
# 2           2024-09-01           In               769
# 3           2024-06-06          Out               398
# 4           2024-05-22           In               236

# %%
# set(purchase_df['MaterialID']).intersection(set(stores_df['MaterialID']))

# %%
# --- Production Data ---
production_data = {
    'ProductionID': [fake.uuid4() for _ in range(num_records)],
    'ProductID': [f'P{random.randint(100, 999)}' for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'ProductionDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'JobWorkID': [f'JW{random.randint(1000, 9999)}' if random.random() < 0.5 else None for _ in range(num_records)],
    'RawMaterialConsumption': [random.randint(1, 50) for _ in range(num_records)],
    'ProductionQuantity': [random.randint(1, 200) for _ in range(num_records)]
}
production_df = pd.DataFrame(production_data)
production_df.head()
# Out:
#                            ProductionID ProductID MaterialID ProductionDate  \
# 0  a2dddb54-9f5d-4d4c-bccf-1cd129f422bc      P536       M382     2024-03-27
# 1  91ed0191-9dbe-4742-ab2f-f3b499627f2c      P809       M407     2025-02-21
# 2  54bec732-e8f6-4d87-8acc-adde12e66ca5      P683       M494     2024-12-09
# 3  83145984-2888-4680-972a-ec3b470534ed      P702       M494     2024-05-08
# 4  5cadcab6-4cf3-4044-95de-1056bb934833      P715       M961     2024-05-30
#
#   JobWorkID  RawMaterialConsumption  ProductionQuantity
# 0      None                      10                 174
# 1      None                      40                 157
# 2      None                      16                   4
# 3      None                      40                 135
# 4    JW3624                      41                  17

# %%
# --- Maintenance Data ---
maintenance_data = {
    'MaintenanceID': [fake.uuid4() for _ in range(num_records)],
    'MachineID': [f'MC{random.randint(100, 999)}' for _ in range(num_records)],
    'MaintenanceDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'MaintenanceType': [random.choice(['Preventive', 'Corrective']) for _ in range(num_records)],
    'MaintenanceCost': [round(random.uniform(100, 5000), 2) for _ in range(num_records)],
}
maintenance_df = pd.DataFrame(maintenance_data)
maintenance_df.head()
# Out:
#                           MaintenanceID MachineID MaintenanceDate  \
# 0  90fe7a39-4362-45be-b847-8c175d0300f0     MC446      2024-05-07
# 1  742edd0d-6634-4810-a6b0-ae9345f0ebcf     MC222      2024-07-09
# 2  533d1980-64d7-405d-b4a2-bb75b05b4127     MC563      2024-11-12
# 3  6f600da4-f580-47b6-8ac2-8abd6f808c7b     MC546      2024-06-09
# 4  beefccbb-904e-406a-9fe3-0807f24e9849     MC404      2024-08-03
#
#   MaintenanceType  MaintenanceCost
# 0      Corrective          1746.11
# 1      Preventive          1271.88
# 2      Preventive          4866.47
# 3      Preventive          4912.82
# 4      Corrective          2128.16

# %%
# --- Quality Data ---
quality_data = {
    'QualityID': [fake.uuid4() for _ in range(num_records)],
    'MaterialID': [f'M{random.randint(100, 999)}' for _ in range(num_records)],
    'InspectionDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'InspectionResult': [random.choice(['Pass', 'Fail']) for _ in range(num_records)],
    'ValidationDate': [fake.date_between(start_date='-1y', end_date='today') if random.random() < 0.7 else None for _ in range(num_records)]
}
quality_df = pd.DataFrame(quality_data)
quality_df.head()
# Out:
#                               QualityID MaterialID InspectionDate  \
# 0  3b22f9a7-aa2f-4bbe-96e7-50a4f5f5c221       M346     2024-05-18
# 1  52aa6c25-b04a-4153-85b3-501df6f9fc09       M892     2024-08-09
# 2  2cf571ef-a872-4a84-9bc7-abf9e2150a7f       M850     2024-09-08
# 3  fc377327-8f07-45fd-a1ea-f0b975e358e8       M724     2024-12-22
# 4  8862bb93-db37-47dd-9034-bcf68da9af51       M887     2024-10-14
#
#   InspectionResult ValidationDate
# 0             Fail     2024-10-16
# 1             Pass     2025-02-04
# 2             Pass     2024-12-23
# 3             Pass           None
# 4             Fail     2024-06-21

# %%
# --- Dispatch & Logistics Data ---
dispatch_data = {
    'DispatchID': [fake.uuid4() for _ in range(num_records)],
    'SalesID': [sales_df['SalesID'].sample(n=1).iloc[0] for _ in range(num_records)],
    'TransportPartner': [fake.company() for _ in range(num_records)],
    'DeliveryDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'TrackingNumber': [f'TN{random.randint(100000, 999999)}' for _ in range(num_records)],
}
dispatch_df = pd.DataFrame(dispatch_data)
dispatch_df.head()
# Out:
#                              DispatchID                               SalesID  \
# 0  2cb9467b-783e-458c-af34-1fee926bb699  4adbe0f8-e7fd-48df-a4f2-28b57e278cb1
# 1  0555c221-48be-4738-8a1c-216ad3101eb3  dc515de9-70ae-4c47-b80b-d5a979f5e184
# 2  67dafed7-e88e-4caa-92be-44926239176d  24578744-7fbd-46df-a598-ade630b628e1
# 3  2aec14c8-7ada-4a82-88cd-ea22fab79315  f22a5964-968c-442b-9d08-7c99816b7bb4
# 4  f5b0ab73-e240-4a71-9b56-2ea1481b1ae8  ccb18f8c-6c25-4412-b944-96310b852d77
#
#     TransportPartner DeliveryDate TrackingNumber
# 0         Mccall PLC   2025-03-05       TN730052
# 1          Klein LLC   2024-11-07       TN140185
# 2  Lawrence-Stafford   2025-03-10       TN171248
# 3         Flores Inc   2025-03-09       TN574454
# 4      Mcfarland Inc   2024-05-16       TN450387

# %%
# --- HR & Admin Data ---
hr_data = {
    'EmployeeID': [fake.uuid4() for _ in range(num_records)],
    'EmployeeName': [fake.name() for _ in range(num_records)],
    'HireDate': [fake.date_between(start_date='-5y', end_date='-1y') for _ in range(num_records)],
    'Department': [random.choice(['Sales', 'Planning', 'Purchase', 'Stores', 'Production', 'Maintenance', 'Quality', 'Logistics', 'HR', 'Finance']) for _ in range(num_records)],
    'Salary': [round(random.uniform(30000, 150000), 2) for _ in range(num_records)],
    'PayrollDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
}
hr_df = pd.DataFrame(hr_data)
hr_df.head()
# Out:
#                              EmployeeID      EmployeeName    HireDate  \
# 0  c0da5043-2270-4891-aec1-3a61dbe50d1f      Tammy Taylor  2023-09-25
# 1  29ec23ed-1d70-44c5-aeca-d06e775d14ea  Jennifer Skinner  2020-07-12
# 2  bbc5ef78-c245-477e-9cf6-48c80b54ea5a        Emily Hart  2023-07-14
# 3  e2a61566-bc2f-4d44-830d-d3e0ad721a38  Katherine Riddle  2024-03-11
# 4  89c7bf24-d74e-45d0-a45c-9c6298175483        Tonya Pham  2022-08-31
#
#   Department     Salary PayrollDate
# 0     Stores  147740.91  2024-12-02
# 1   Purchase  123698.06  2024-11-06
# 2     Stores   41618.35  2025-02-22
# 3    Finance   67994.60  2024-08-18
# 4   Planning  123306.58  2024-07-14

# %%
# --- Accounts & Finance Data ---
finance_data = {
    'TransactionID': [fake.uuid4() for _ in range(num_records)],
    'AccountID': [fake.uuid4() for _ in range(num_records)],
    'TransactionDate': [fake.date_between(start_date='-1y', end_date='today') for _ in range(num_records)],
    'TransactionType': [random.choice(['Credit', 'Debit']) for _ in range(num_records)],
    'Amount': [round(random.uniform(500, 100000), 2) for _ in range(num_records)],
    'GST_Compliance': [random.choice([True, False]) for _ in range(num_records)],
}
finance_df = pd.DataFrame(finance_data)
finance_df.head()
# Out:
#                           TransactionID                             AccountID  \
# 0  6c9be132-6468-4245-b755-c97fb8dbc5c5  45d6f1cb-f9e7-41ad-b200-d4e252c894da
# 1  5c76db1d-422c-4d16-a5c3-63a4387e6b20  189ec596-4219-4080-be06-2c5b6500217a
# 2  0f8f263d-1768-402b-be2f-85dfb0866826  7b3ef9cd-b48b-49b2-9722-11582463e4b9
# 3  f91aa09c-f0c3-4b48-a661-b8d16b5d5c43  e23b32a1-3a0c-49dc-b940-beb78c5d9f83
# 4  838515ef-a09c-4ff7-9051-fd8c40ce19e5  d895b7fc-eaee-4867-9433-a3c4bf24504d
#
#   TransactionDate TransactionType    Amount  GST_Compliance
# 0      2024-06-02           Debit  70388.99           False
# 1      2024-09-29           Debit  63972.29           False
# 2      2024-07-08           Debit  20186.75            True
# 3      2024-06-11          Credit  51241.44            True
# 4      2024-08-13          Credit   4265.19           False

# %%
# --- Settings Data ---
settings_data = {
    'SettingID': [fake.uuid4() for _ in range(10)],
    'SettingName': [random.choice(['Tax Rate', 'Discount Policy', 'Currency', 'Payment Terms', 'Return Policy']) for _ in range(10)],
    'SettingValue': [random.choice(['5%', '10%', 'USD', 'Net 30', 'No Returns']) for _ in range(10)],
    'LastUpdated': [fake.date_between(start_date='-1y', end_date='today') for _ in range(10)],
}
settings_df = pd.DataFrame(settings_data)
settings_df.head()
# Out:
#                               SettingID      SettingName SettingValue  \
# 0  fc2268ac-c3d7-43ad-a8e6-fd622f28790e    Payment Terms   No Returns
# 1  92f197d8-800c-4dc0-a646-510043f14c89    Payment Terms       Net 30
# 2  e89d6bd2-46b0-4461-a91f-218c928dd009  Discount Policy          10%
# 3  6b190a14-cd93-45ed-86b0-df5bc62b9ba4  Discount Policy   No Returns
# 4  8d5519c1-acd7-4204-ab05-975c72794714    Return Policy          USD
#
#   LastUpdated
# 0  2024-11-19
# 1  2024-04-13
# 2  2024-10-05
# 3  2024-10-07
# 4  2025-03-04

# %%
# Number of employees
num_employees = 100

# Generate employee data
employee_data = {
    'EmployeeID': [fake.uuid4() for _ in range(num_employees)],
    'EmployeeName': [fake.name() for _ in range(num_employees)],
    'Department': [random.choice(['Sales', 'Planning', 'Purchase', 'Stores', 'Production', 'Maintenance', 'Quality', 'Dispatch', 'HR', 'Accounts', 'Settings']) for _ in range(num_employees)],
    'JobTitle': [fake.job() for _ in range(num_employees)],
    'AccessLevel': [random.choice(['Full', 'Limited', 'None']) for _ in range(num_employees)],
    'SalesAccess': [random.choice([True, False]) if random.choice(['Sales', 'Accounts']) == random.choice(['Sales', 'Accounts']) else False for _ in range(num_employees)],
    'PlanningAccess': [random.choice([True, False]) if random.choice(['Planning', 'Accounts']) == random.choice(['Planning', 'Accounts']) else False for _ in range(num_employees)],
    'PurchaseAccess': [random.choice([True, False]) if random.choice(['Purchase', 'Accounts']) == random.choice(['Purchase', 'Accounts']) else False for _ in range(num_employees)],
    'StoresAccess': [random.choice([True, False]) if random.choice(['Stores', 'Production']) == random.choice(['Stores', 'Production']) else False for _ in range(num_employees)],
    'ProductionAccess': [random.choice([True, False]) if random.choice(['Production', 'Stores']) == random.choice(['Production', 'Stores']) else False for _ in range(num_employees)],
    'MaintenanceAccess': [random.choice([True, False]) if random.choice(['Maintenance', 'Quality']) == random.choice(['Maintenance', 'Quality']) else False for _ in range(num_employees)],
    'QualityAccess': [random.choice([True, False]) if random.choice(['Quality', 'Maintenance']) == random.choice(['Quality', 'Maintenance']) else False for _ in range(num_employees)],
    'DispatchAccess': [random.choice([True, False]) if random.choice(['Dispatch', 'Sales']) == random.choice(['Dispatch', 'Sales']) else False for _ in range(num_employees)],
    'HRAccess': [random.choice([True, False]) if random.choice(['HR', 'Accounts', 'Settings']) == random.choice(['HR', 'Accounts', 'Settings']) else False for _ in range(num_employees)],
    'AccountsAccess': [random.choice([True, False]) if random.choice(['Accounts', 'Settings']) == random.choice(['Accounts', 'Settings']) else False for _ in range(num_employees)],
    'SettingsAccess': [random.choice([True, False]) if random.choice(['Settings', 'Accounts']) == random.choice(['Settings', 'Accounts']) else False for _ in range(num_employees)],
}

employee_df = pd.DataFrame(employee_data)
employee_df.head()
# Out:
#                              EmployeeID     EmployeeName Department  \
# 0  af2af254-7906-4bcc-9f48-017d0272565e    Richard Davis   Accounts
# 1  1902f73b-5030-4843-b2c2-7222e6937975   Bianca Garrett   Settings
# 2  e6215472-f44d-408f-843f-cecc24286407   Melinda Thomas   Dispatch
# 3  d629dacb-dccc-4b4a-b310-b2ce96ae03cc   Kenneth Lowe V   Planning
# 4  a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04  Jessica Johnson      Sales
#
#                    JobTitle AccessLevel  SalesAccess  PlanningAccess  \
# 0       Programmer, systems        None         True            True
# 1   Physiological scientist        Full        False           False
# 2       Librarian, academic        None        False           False
# 3  Doctor, general practice        Full        False           False
# 4        Personal assistant     Limited        False           False
#
#    PurchaseAccess  StoresAccess  ProductionAccess  MaintenanceAccess  \
# 0           False         False             False              False
# 1           False         False              True              False
# 2            True         False             False              False
# 3           False         False              True              False
# 4           False         False              True              False
#
#    QualityAccess  DispatchAccess  HRAccess  AccountsAccess  SettingsAccess
# 0          False           False      True            True            True
# 1           True           False     False           False            True
# 2          False           False     False           False           False
# 3          False           False     False            True            True
# 4          False           False     False           False           False

# %%
# Save to CSV files
sales_df.to_csv('../db/sales_data.csv', index=False)
planning_df.to_csv('../db/planning_data.csv', index=False)
purchase_df.to_csv('../db/purchase_data.csv', index=False)
stores_df.to_csv('../db/stores_data.csv', index=False)
production_df.to_csv('../db/production_data.csv', index=False)
maintenance_df.to_csv('../db/maintenance_data.csv', index=False)
quality_df.to_csv('../db/quality_data.csv', index=False)
dispatch_df.to_csv('../db/dispatch_data.csv', index=False)
hr_df.to_csv('../db/hr_data.csv', index=False)
finance_df.to_csv('../db/finance_data.csv', index=False)
settings_df.to_csv('../db/settings_data.csv', index=False)
employee_df.to_csv('../db/employees_data.csv', index=False)

print("Sample data generated and saved successfully.")
# Out:
# Sample data generated and saved successfully.

# %%
import os
import glob
import pymongo
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

# Connect to MongoDB
client = pymongo.MongoClient(os.environ['MONGO_URI'])
db = client["hack_ai_thon"]

# List of CSV files and their corresponding MongoDB collections
csv_files = {
    "sales_data.csv": "Sales_NPD",
    "planning_data.csv": "Planning",
    "purchase_data.csv": "Purchase",
    "stores_data.csv": "Stores",
    "production_data.csv": "Production",
    "maintenance_data.csv": "Maintenance",
    "quality_data.csv": "Quality",
    "dispatch_data.csv": "Dispatch_Logistics",
    "hr_data.csv": "HR_Admin",
    "finance_data.csv": "Accounts_Finance",
    "settings_data.csv": "Settings",
    "employees_data.csv" : "Employees"
}

# %%
# Function to upload CSV data to MongoDB
def upload_to_mongodb(csv_filename, collection_name):
    collection = db[collection_name] 
    df = pd.read_csv(csv_filename)
    data = df.to_dict(orient="records")
    collection.insert_many(data)
    print(f"Uploaded {len(data)} records to {collection_name}")

for path in glob.glob("db/*.csv"):
    upload_to_mongodb(path, csv_files[path.split('\\')[-1]])
print("All data uploaded successfully to MongoDB.")
# Out:
# Uploaded 500 records to Dispatch_Logistics
# Uploaded 500 records to Accounts_Finance
# Uploaded 500 records to HR_Admin
# Uploaded 500 records to Maintenance
# Uploaded 500 records to Planning
# Uploaded 500 records to Production
# Uploaded 500 records to Purchase
# Uploaded 500 records to Quality
# Uploaded 500 records to Sales_NPD
# Uploaded 10 records to Settings
# Uploaded 500 records to Stores
# All data uploaded successfully to MongoDB.

# %%
# !pip install nltk pdfplumber faiss-cpu sentence-transformers

# %%
import re
import faiss
import pdfplumber
from nltk.stem import WordNetLemmatizer
from langchain.vectorstores import FAISS
from sentence_transformers import SentenceTransformer
from langchain.schema import Document
from langchain.docstore import InMemoryDocstore
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from langchain.text_splitter import SentenceTransformersTokenTextSplitter

model = SentenceTransformer('all-MiniLM-L6-v2')
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in ENGLISH_STOP_WORDS]
    return ' '.join(tokens)


def gen_embeddings(texts):
    return model.encode(texts)

# %%
pdf = pdfplumber.open("../db/Sample-Code-of-Conduct-for-Small-and-Medium-Enterprises.pdf")

text = ""
for page in pdf.pages:
    text += page.extract_text() + "\n"

text_splitter = SentenceTransformersTokenTextSplitter(chunk_overlap=50, tokens_per_chunk=384)
text_chunks = text_splitter.split_text(text)

embeddings = gen_embeddings(text_chunks)
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

documents = [
    Document(page_content=text)
    for text in text_chunks
]
docstore_dict = {str(idx): doc for idx, doc in enumerate(documents)}
docstore = InMemoryDocstore(docstore_dict)
index_to_docstore_id = {i: str(i) for i in range(len(documents))}

vector_store = FAISS(embedding_function=gen_embeddings, index=index, docstore=docstore, index_to_docstore_id=index_to_docstore_id)
retriever = vector_store.as_retriever()
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
import pandas as pd

employee_df = pd.read_csv("../db/employees_data.csv")
employee_df.head()
# Out:
#                              EmployeeID     EmployeeName Department  \
# 0  af2af254-7906-4bcc-9f48-017d0272565e    Richard Davis   Accounts
# 1  1902f73b-5030-4843-b2c2-7222e6937975   Bianca Garrett   Settings
# 2  e6215472-f44d-408f-843f-cecc24286407   Melinda Thomas   Dispatch
# 3  d629dacb-dccc-4b4a-b310-b2ce96ae03cc   Kenneth Lowe V   Planning
# 4  a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04  Jessica Johnson      Sales
#
#                    JobTitle AccessLevel  SalesAccess  PlanningAccess  \
# 0       Programmer, systems         NaN         True            True
# 1   Physiological scientist        Full        False           False
# 2       Librarian, academic         NaN        False           False
# 3  Doctor, general practice        Full        False           False
# 4        Personal assistant     Limited        False           False
#
#    PurchaseAccess  StoresAccess  ProductionAccess  MaintenanceAccess  \
# 0           False         False             False              False
# 1           False         False              True              False
# 2            True         False             False              False
# 3           False         False              True              False
# 4           False         False              True              False
#
#    QualityAccess  DispatchAccess  HRAccess  AccountsAccess  SettingsAccess
# 0          False           False      True            True            True
# 1           True           False     False           False            True
# 2          False           False     False           False           False
# 3          False           False     False            True            True
# 4          False           False     False           False           False

# %%
import random

employees_split = employee_df['EmployeeName'].str.split()
emails = [".".join(split[:2]).lower() + "@gmail.com" for split in employees_split]
passwords = [str(random.randrange(100000, 999999)) for _ in range(len(employee_df))]
employee_df['EmployeeEmail'] = emails
employee_df['EmployeePassword'] = passwords

# %%
employee_df.head()
# Out:
#                              EmployeeID     EmployeeName Department  \
# 0  af2af254-7906-4bcc-9f48-017d0272565e    Richard Davis   Accounts
# 1  1902f73b-5030-4843-b2c2-7222e6937975   Bianca Garrett   Settings
# 2  e6215472-f44d-408f-843f-cecc24286407   Melinda Thomas   Dispatch
# 3  d629dacb-dccc-4b4a-b310-b2ce96ae03cc   Kenneth Lowe V   Planning
# 4  a3237c33-229e-4d4b-9fe8-8b2f3f2b3d04  Jessica Johnson      Sales
#
#                    JobTitle AccessLevel  SalesAccess  PlanningAccess  \
# 0       Programmer, systems         NaN         True            True
# 1   Physiological scientist        Full        False           False
# 2       Librarian, academic         NaN        False           False
# 3  Doctor, general practice        Full        False           False
# 4        Personal assistant     Limited        False           False
#
#    PurchaseAccess  StoresAccess  ProductionAccess  MaintenanceAccess  \
# 0           False         False             False              False
# 1           False         False              True              False
# 2            True         False             False              False
# 3           False         False              True              False
# 4           False         False              True              False
#
#    QualityAccess  DispatchAccess  HRAccess  AccountsAccess  SettingsAccess  \
# 0          False           False      True            True            True
# 1           True           False     False           False            True
# 2          False           False     False           False           False
# 3          False           False     False            True            True
# 4          False           False     False           False           False
#
#                EmployeeEmail EmployeePassword
# 0    richard.davis@gmail.com           534199
# 1   bianca.garrett@gmail.com           251575
# 2   melinda.thomas@gmail.com           442853
# 3     kenneth.lowe@gmail.com           487852
# 4  jessica.johnson@gmail.com           649565

# %%
employee_df.to_csv("../db/employees_data_with_password.csv", index=False)

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient

load_dotenv()

mongo_client = MongoClient(os.environ.get("MONGO_URI"))
mongo_db = mongo_client['hack_ai_thon']
collection = mongo_db['Employees']

# %%
import requests

BASE_URL = "http://127.0.0.1:5000"

def create_user(user):
    url = f"{BASE_URL}/sign-up"
    response = requests.post(url, json=user)
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": f"Failed to create user: {response.text}"}


employee_df.fillna(value='None', inplace=True)
for idx, emp in employee_df.iterrows():
    user_response = create_user(emp.to_dict())
    print(user_response)
# Out:
# {'data': {'session': {'created_at': '2025-03-23 04:09:35.439103', 'expires_at': '2025-03-24 04:09:35.439103', 'session_token': '819d585c01ff6a2da056ac45d7c774fff55dd93ce0cb05ecfc18e264c42dd1c8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:35.712172', 'expires_at': '2025-03-24 04:09:35.712172', 'session_token': '086fe49ec76f985d42f18e7c79197fbb46f9bc9d3cb7bf7bb08c37cf71f17ed7'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:35.980274', 'expires_at': '2025-03-24 04:09:35.980274', 'session_token': 'ce3711ad88ab528ff787614a7eede1a93026bff06201af30684c05fbf4eee37b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:36.261296', 'expires_at': '2025-03-24 04:09:36.261296', 'session_token': '0309606ddcbf546af15587dd668c0c33253400d6ba35c2d6ed20bca4e0507411'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:36.531729', 'expires_at': '2025-03-24 04:09:36.531729', 'session_token': 'e1c4c3b50615b35921f1de1caf45b32b084b07fbd569e2e17485d05b57b51f74'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:36.813196', 'expires_at': '2025-03-24 04:09:36.813196', 'session_token': 'e47ed16222a303227b7810be68fa6dd6b423fff002af5e007a0a847e3aef6b61'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:37.086377', 'expires_at': '2025-03-24 04:09:37.086377', 'session_token': '733242bb1af1d02fecdf2c635e4c7172e71f42a097c0bb8c8b08b1b94e9628d5'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:37.366178', 'expires_at': '2025-03-24 04:09:37.366178', 'session_token': 'b29d4495bd8036aa35c37986fc26251e94afb502fa943d233228e44b032d9bfb'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:37.638382', 'expires_at': '2025-03-24 04:09:37.638382', 'session_token': '99108eeb263b15caadf633218cfc5d1e3f90afc6409329ba23d4883c8be74f0f'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:37.900867', 'expires_at': '2025-03-24 04:09:37.900867', 'session_token': '715924201f8e323a576004c92f4e22d67a3adf50ff984379697bc15e062b0125'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:38.191840', 'expires_at': '2025-03-24 04:09:38.191840', 'session_token': '8137ec125b31b604096c0cd3a45f0f1a537ac6a3ead29285659693a933341332'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:38.464187', 'expires_at': '2025-03-24 04:09:38.464187', 'session_token': 'c8a4057a61bb48e419b9ad7a1a219fc590940ac04b847f016849474c4b44b741'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:38.738342', 'expires_at': '2025-03-24 04:09:38.738342', 'session_token': '69bbf1bd1d806ba3b353e361bbb288d4a83071d6da3be2757268e58161ac25cf'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:39.010417', 'expires_at': '2025-03-24 04:09:39.010417', 'session_token': '27eeba53fe56019e82477e386bb53fcbe5beb04b663af4d5c770ec4fa3e57a34'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:39.285233', 'expires_at': '2025-03-24 04:09:39.285233', 'session_token': '1a8ffd8320eee80e8d9da5307c6c8f15bf7b7a52548526fdd66643c4eae3e538'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:39.557243', 'expires_at': '2025-03-24 04:09:39.557243', 'session_token': '7ef73abe5a01088ed41f7045b3bed3824e84f06d9ba3d21addf27729f42fb825'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:39.827642', 'expires_at': '2025-03-24 04:09:39.827642', 'session_token': '01ef912ed0b2fc8443577c807d36a3585050129f1160deef4ef2a46aa7190a35'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:40.100592', 'expires_at': '2025-03-24 04:09:40.100592', 'session_token': 'da83bdccfd3ba79e0de20d638231e1b11ab1de838e851815889aa7234c0def92'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:40.372201', 'expires_at': '2025-03-24 04:09:40.372201', 'session_token': '8119e01d563a0dc319ab722bf20489e68548ced8877175d4ec34c4194ef4438d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:40.650686', 'expires_at': '2025-03-24 04:09:40.650686', 'session_token': '8c5f2c898af9dbfabbfab4eb596bbd1e904954e9a9a46983cdec4fa62634da94'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:40.938253', 'expires_at': '2025-03-24 04:09:40.938253', 'session_token': '230a308efdc02e1349c7e7a242ccd1b91501f9bac0fd4970c958da437d924540'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:41.229041', 'expires_at': '2025-03-24 04:09:41.229041', 'session_token': '6700a439875abe8aaf08379c29ae1e6b8cfd07efabcf5f154760833ad6e77e2c'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:41.501318', 'expires_at': '2025-03-24 04:09:41.501318', 'session_token': '2088503f3bf6503e9743ffdb96bf7d8d3cf6346f6a0b8b0836f94aeb62278cf0'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:41.770763', 'expires_at': '2025-03-24 04:09:41.770763', 'session_token': 'b7c6b24da7ec95d910f9fa4550ff8b4077ef6535e8651aaaa2b82f95af58a755'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:42.044251', 'expires_at': '2025-03-24 04:09:42.044251', 'session_token': '658c9f92871a33db540cbc6070e933d57e5f67694515cda9852b96eafccbbc0f'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:42.316275', 'expires_at': '2025-03-24 04:09:42.316275', 'session_token': '7eef37e61d44f7308f7987f10190c17742befdc793fe732d50269e93a4b97764'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:42.587619', 'expires_at': '2025-03-24 04:09:42.587619', 'session_token': 'f9a17edf44758361676656c4ea55321fe738fa4d0e9d0b50a37f885c4e615be9'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:42.855435', 'expires_at': '2025-03-24 04:09:42.855435', 'session_token': '5aeff8b62c10c1c7b9c52fb1c32709bc56f0fe2415f23f90cb854af75903f794'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:43.138736', 'expires_at': '2025-03-24 04:09:43.138736', 'session_token': 'b2c872e129fc6384bd8c1b5022b37f2e987f18d8aa76dc5c6bfad5352740e775'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:43.410792', 'expires_at': '2025-03-24 04:09:43.410792', 'session_token': 'a4bd45d8e6c22f36f508154770a657e0d495f51f48911456ad865bb76339abff'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:43.687046', 'expires_at': '2025-03-24 04:09:43.687046', 'session_token': '31edb1ad734f524ecf94e4629697fd7295e3c85f6d07f75977d40b5aa8b8e9ec'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:43.959176', 'expires_at': '2025-03-24 04:09:43.959176', 'session_token': '7386a03dd7f9285cbd2a311407d059ee2c3c42d6bd280009e89467576899bdb8'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:44.252377', 'expires_at': '2025-03-24 04:09:44.252377', 'session_token': 'ec52d3dede8e9648541c96a24c58f531b0b135babe6cda4a961383476f0524c9'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:44.528041', 'expires_at': '2025-03-24 04:09:44.528041', 'session_token': '037c1f43e9d1298d37a4527492c0fd1ecd5555cbd891d2f3de28fd721a17f405'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:44.798676', 'expires_at': '2025-03-24 04:09:44.798676', 'session_token': '209a1eb5a0684edfe990ddd7d01748d4da9d6fd4ea91cee03bb04b09ab119cfa'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:45.074050', 'expires_at': '2025-03-24 04:09:45.074050', 'session_token': 'e8d12432e825895a240fa1275a49f736225ce996a719b2c1ce84b6012acee34d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:45.345067', 'expires_at': '2025-03-24 04:09:45.345067', 'session_token': '3f0268d661cc3d9364b95f470f845f9e55b8f83132c3ca82bc8d81f799e2ddcb'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:45.620438', 'expires_at': '2025-03-24 04:09:45.620438', 'session_token': '874d6c3209301844eb534972ba63aa2710c60005e0a499aaf10110df2ef793e2'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:45.910909', 'expires_at': '2025-03-24 04:09:45.910909', 'session_token': '1d133d2feff0570eaed7dded64703c507554cfb67a14db8564cfb7e054c3989d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:46.182255', 'expires_at': '2025-03-24 04:09:46.182255', 'session_token': 'd5e7ea2f003e90752456f03aeca67c66ff75a80813770fedca2294f345713a33'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:46.456534', 'expires_at': '2025-03-24 04:09:46.456534', 'session_token': '86cf44d9ef5dafff833a5c5b82693b78d98f9d342377b22eaaa904feacdffc8a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:46.728885', 'expires_at': '2025-03-24 04:09:46.728885', 'session_token': '2cfc827dd78ba6e9165ecdd71da186520f239795018a47e28739fff2023e701b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:47.013905', 'expires_at': '2025-03-24 04:09:47.013905', 'session_token': 'd19c721fe7f61f34b830851c61bded8306f931ddb22455278fc4e292762e246d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:47.280789', 'expires_at': '2025-03-24 04:09:47.280789', 'session_token': '13f8881e3033bbac7d0f3a26ec622c13c6700b0812d20d0dbf2017cf77939cb6'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:47.555730', 'expires_at': '2025-03-24 04:09:47.555730', 'session_token': '0f687b1e8ebca710ec0e72d6e2589f7c01558d1375b9ffcb50b857f27c785d2c'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:47.832994', 'expires_at': '2025-03-24 04:09:47.832994', 'session_token': '0ec99246ff6c27454a1d26ffc994ebe61aa59cf6eea6265ac988d1fcbbb70f9a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:48.110839', 'expires_at': '2025-03-24 04:09:48.110839', 'session_token': '216fe1441c3bf1baffe4c42578f776d97e1412d621db0f5dab9cfb87ce11e9ac'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:48.382689', 'expires_at': '2025-03-24 04:09:48.382689', 'session_token': 'bff6c37d0e043f99053cee30f76b2896abf49d0a700cd1b3d8abc7a4950de0e9'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:48.657166', 'expires_at': '2025-03-24 04:09:48.657166', 'session_token': '1709ef00e7c27ce7383a8f6f4cebb627bef672d949d54cffa7d92df22975eebe'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:48.935047', 'expires_at': '2025-03-24 04:09:48.935047', 'session_token': '73791cd29e19621512e73a328954e9df22c06e1ab18b92d61ee0482ec2d14d67'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:49.225078', 'expires_at': '2025-03-24 04:09:49.225078', 'session_token': '7cfa74df309c98242bba7a76c34f17bccc14a446c123c0630ffec043d3a46cb6'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:49.511612', 'expires_at': '2025-03-24 04:09:49.511612', 'session_token': 'b3d107c2e5a8671867b8ab31e0897e4451103b321b26a9671312538569407dc3'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:49.786439', 'expires_at': '2025-03-24 04:09:49.786439', 'session_token': '8a913a539d9b622abd930c3aa05fbce6ce66db394a58ce595ef37707a74be663'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:50.058472', 'expires_at': '2025-03-24 04:09:50.058472', 'session_token': '31afc07ca7e9d533d03553e22b48ae1ecb1ba1e96cca1ea2a27890ec1f36d096'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:50.328941', 'expires_at': '2025-03-24 04:09:50.328941', 'session_token': '6818510c9a7b97765fbf8cd9ee9cc33a7c65082266e36201ea72e29fb486205a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:50.603889', 'expires_at': '2025-03-24 04:09:50.603889', 'session_token': '2c7d297181e455d69ae047fb7bcde746d1f364bcc3e0d1fd1db171269a7874fd'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:50.875740', 'expires_at': '2025-03-24 04:09:50.875740', 'session_token': '8dc47accc7e855cc00673837dbef0c95cdaa6e610883d18431de14fc2574ac48'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:51.150713', 'expires_at': '2025-03-24 04:09:51.150713', 'session_token': '5ad3aed7922ea00c6e6b77c41c92b1e06f90df6e1ec442d6f5fd802bb3ddaa5d'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:51.446382', 'expires_at': '2025-03-24 04:09:51.446382', 'session_token': 'ab922035abd7012a41f6d1bc6690653a3265be55aed35cfb280d6a6668a37338'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:51.719288', 'expires_at': '2025-03-24 04:09:51.719288', 'session_token': 'ba22df25c8e7ad93059d8a2fe68a78988ac32c51aba75f75b4d2266d8c9977bd'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:51.990530', 'expires_at': '2025-03-24 04:09:51.990530', 'session_token': 'd71e8ce904b0a7a2583eeed14bd6e052df82383ab9cecd787cf02e2ae6325fe6'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:52.265255', 'expires_at': '2025-03-24 04:09:52.265255', 'session_token': '06419d5da36e6661ae4d9b08b2be3ea583f6889836f58fe216270fd7aa7fe89a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:52.537080', 'expires_at': '2025-03-24 04:09:52.537080', 'session_token': '77c2483ac524d18021b29060087bf81febb34c7ff800b8b7545981c0489f385e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:52.830250', 'expires_at': '2025-03-24 04:09:52.830250', 'session_token': '320e8f8658e5ea7cbdaf99a75ccad4ab382ee61dd050a36003ad5d5d8f0c9ef0'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:53.111792', 'expires_at': '2025-03-24 04:09:53.111792', 'session_token': 'e29f7f462dfae60cf188d658809d6d16fd06f98febf007adf553da2cd59a2370'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:53.384061', 'expires_at': '2025-03-24 04:09:53.384061', 'session_token': 'efb2303b9ac88792415899a3a43dae6fe65fbdfc8fe199d85d44dabb0d75c787'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:53.655404', 'expires_at': '2025-03-24 04:09:53.655404', 'session_token': 'e03540df3a23c828dfce964f3659ce3e10cffec9dd08d58c4477264445250bb7'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:53.926593', 'expires_at': '2025-03-24 04:09:53.926593', 'session_token': '6a4a0eb5673658ec454aef65e18506650658043a6563e9dce59be0ad2de832cd'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:54.200328', 'expires_at': '2025-03-24 04:09:54.200328', 'session_token': 'e8df92d48d4e675f3c9a680eb79f8ea755637cba2d91d49f9e815d673da31da5'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:54.472339', 'expires_at': '2025-03-24 04:09:54.472339', 'session_token': '1d6c29d62b75362cd177e227047615a0834b0ff22d0e840639a571ff85b2fa30'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:54.743689', 'expires_at': '2025-03-24 04:09:54.743689', 'session_token': '566e76bf1dcca07efe354a0dd4943b0fb69cc5cd0db17e11784a08185c047200'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:55.017505', 'expires_at': '2025-03-24 04:09:55.017505', 'session_token': '8219e576a87dba15985d24dc93300ee248c2766acbdceecddc4b46d347cfb627'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:55.290986', 'expires_at': '2025-03-24 04:09:55.290986', 'session_token': 'f9259c523a59abd8276ebdb8eb1010983ee9304c69a34b25963d88b098206b59'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:55.562054', 'expires_at': '2025-03-24 04:09:55.562054', 'session_token': '5b37c91cea4bbcde67b0a21ff3931cd29516de898e0c823ae71d6ce808660616'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:55.833728', 'expires_at': '2025-03-24 04:09:55.833728', 'session_token': 'ad5378b2f40f154c516e8502d9d8ea495b2befcc976c8b082b8bc62a5373c1e0'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:56.104772', 'expires_at': '2025-03-24 04:09:56.104772', 'session_token': '1934c398faf2353749543a9a643c2b3d939e73440b5e43696e337b1f81f12ff0'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:56.376473', 'expires_at': '2025-03-24 04:09:56.376473', 'session_token': 'e76537f4f9e6f57f2007d9ca85afe21f8977910c6c86168a360c30c8600a0bb6'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:56.651309', 'expires_at': '2025-03-24 04:09:56.651309', 'session_token': 'b3bfe6962fdb83dd9d8a9b40d25e826d4edd3b9c327586149696bf0ee503e29f'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:56.931310', 'expires_at': '2025-03-24 04:09:56.931310', 'session_token': '2c9764a9d6bd4ad7c9f27218e97c72c66689467c7e97660a8d41d9e7e5b79c34'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:57.203513', 'expires_at': '2025-03-24 04:09:57.203513', 'session_token': 'c9377198a23f2a10ef681d977d0160e03a793b8ccca759b42c203cc355aa1b6e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:57.474331', 'expires_at': '2025-03-24 04:09:57.474331', 'session_token': 'a5a1644cde433564e5250c6880bbbef4aab0933a6098fd4abb83ac9fc5ae1ef4'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:57.745261', 'expires_at': '2025-03-24 04:09:57.745261', 'session_token': '7103d2612760d185e0435d3052dc29290f42f935af801b6a928b3f182e719f74'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:58.021949', 'expires_at': '2025-03-24 04:09:58.021949', 'session_token': '1c3f774960d0c3503a788614dd09db747b0c1aa0bae5724a2b8a8f6b1e35af57'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:58.295161', 'expires_at': '2025-03-24 04:09:58.295161', 'session_token': '9df775474674dd9a49b974f1826e3aa0daeb66753f43f0bfcd03218167b14ab7'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:58.567564', 'expires_at': '2025-03-24 04:09:58.567564', 'session_token': '11de457d1a524230fceeb6ab3029f3d3667f8025aa82226eebd589c9d25fb581'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:58.849840', 'expires_at': '2025-03-24 04:09:58.849840', 'session_token': 'dc57c27a9dba6f71f371ef10afda17abca197924bd78a161e6f5dd32dc1c764c'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:59.131526', 'expires_at': '2025-03-24 04:09:59.131526', 'session_token': '90638c483bb6e81d0e0cb4adcdd6c2b9dfd104169f1244e01b2914ae853ea637'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:59.405221', 'expires_at': '2025-03-24 04:09:59.405221', 'session_token': 'bf867553a03cf7a83b1474dc917528c852c2bb3611cebd555b5a232dce05cae4'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:59.677384', 'expires_at': '2025-03-24 04:09:59.676478', 'session_token': '945ced73e6acd8191fbce567afec85eb36270d1ad0c35846aca7fb2a02e44136'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:09:59.949136', 'expires_at': '2025-03-24 04:09:59.949136', 'session_token': '76547c46eca91c32949f7093cef56595d2e03864fa2b1f3415181d79df2510c2'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:00.224087', 'expires_at': '2025-03-24 04:10:00.224087', 'session_token': '6a57601d97c94a9458375f8e36fac058d2c10c7a0f590a58270176cd610bf006'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:00.496485', 'expires_at': '2025-03-24 04:10:00.496485', 'session_token': '38a0929e51ceb430a1d1172227feaba5e0b6d4cf04adf16d5f6719363d940200'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:00.767703', 'expires_at': '2025-03-24 04:10:00.767703', 'session_token': '9b5c41e362acc1b400cb2b16419e8091dd689a25939ef28e8ced72a0f63a5cb7'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:01.041231', 'expires_at': '2025-03-24 04:10:01.041231', 'session_token': '4e491666aecbd577bdf22db7391cca81f5499a821230dce4a8fc76ef5968f418'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:01.316009', 'expires_at': '2025-03-24 04:10:01.316009', 'session_token': '6e6d7461a1624f470781e0f6950983d598284846db09dd1bb3cb476c08382409'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:01.587235', 'expires_at': '2025-03-24 04:10:01.587235', 'session_token': 'b71c060a14c44cdd8d6047776c4ee8d79fb7058eb6717aa9d4e4e48e5319a4a5'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:01.857465', 'expires_at': '2025-03-24 04:10:01.857465', 'session_token': '5719766575358d61dd1b874bd3e79ac4144a0ff2f7c2bdc96844b172c692992b'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:02.133370', 'expires_at': '2025-03-24 04:10:02.133370', 'session_token': '3c19d9907c1ca1686f27e2369389624cbe14cb183d9f4a75102abb6def94446e'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:02.408393', 'expires_at': '2025-03-24 04:10:02.408393', 'session_token': 'ccaa0647473027d8a67c94ad4a5004e3c0a1c5f97349357efcf8fe8beba91b1a'}}, 'message': 'Session created successfully'}
# {'data': {'session': {'created_at': '2025-03-23 04:10:02.688911', 'expires_at': '2025-03-24 04:10:02.688911', 'session_token': '7cba3b2d47cb7faa2068d72b1e7476308eec4d539dd3c8f5f44eb63d9422c489'}}, 'message': 'Session created successfully'}
